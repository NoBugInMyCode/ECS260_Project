# %%
from tqdm import tqdm
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import torch
import ast

# %%
df = pd.read_csv('C:/Users/29400/Desktop/data/original_data.csv')
df["topics"] = df["topics"].apply(ast.literal_eval)
model = SentenceTransformer("all-MiniLM-L6-v2")

# %%
tqdm.pandas()
predefined_topics = [
    "artificial-intelligence",
    "computer-vision",
    "web-development",
    "cybersecurity",
    "cloud-computing",
    "blockchain",
    "data-science",
    "education",
    "system"
]
predefined_embeddings = model.encode(predefined_topics, convert_to_tensor=True)
def match_topic(repo_topics):
    if not repo_topics:  # 如果 topic 为空，返回 "Unknown"
        return "Unknown"

    # 计算所有 `repo_topics` 的 embedding 并取平均值
    repo_embeddings = model.encode(repo_topics, convert_to_tensor=True)
    avg_repo_embedding = torch.mean(repo_embeddings, dim=0, keepdim=True)  # 计算平均 embedding

    # 计算 repo embedding 与 predefined topics 之间的相似度
    similarities = util.pytorch_cos_sim(avg_repo_embedding, predefined_embeddings)

    # 选择相似度最高的 predefined topic
    best_match_idx = torch.argmax(similarities)
    best_match = predefined_topics[best_match_idx]

    # print(f"{repo_topics} -> {best_match} (Similarity: {similarities[0][best_match_idx]:.4f})")
    return best_match

df["classified_topic"] = df["topics"].progress_apply(match_topic)
# Out:
#   0%|          | 17/185876 [00:00<36:29, 84.89it/s]
# ['docker', 'miui', 'python', 'xiaomi'] -> system (Similarity: 0.3459)
# ['android', 'game', 'game-development', 'ios', 'java', 'libgdx'] -> system (Similarity: 0.4498)
# ['camera', 'embedded-project', 'esp32', 'esp32-cam', 'esp8266', 'espressif', 'firebase', 'firebase-database', 'firebase-realtime-database', 'flutter', 'gfx', 'gui', 'iot-project', 'lvgl', 'mcu', 'mqtt', 'tutorial'] -> system (Similarity: 0.4562)
# ['diskstation', 'dsm', 'rackstation', 'synology', 'synology-disk-station', 'synology-dsm', 'synology-nas'] -> data-science (Similarity: 0.4143)
# ['diskstation', 'dsm', 'rackstation', 'synology', 'synology-disk-station', 'synology-dsm', 'synology-nas'] -> data-science (Similarity: 0.4143)
# ['ajp', 'cnvd-2020-10487', 'cve-2020-1938', 'exp', 'ghostcat'] -> system (Similarity: 0.4268)
# ['flask', 'jieba', 'news', 'search-engine'] -> data-science (Similarity: 0.4253)
# ['jq', 'json', 'query', 'rust'] -> system (Similarity: 0.3921)
# ['arsenal', 'exploitation', 'faraday', 'kali', 'metasploit', 'openvas', 'penetration-testing', 'pentest-tool', 'pentesting-tools', 'scanning', 'vulnerabilities'] -> cybersecurity (Similarity: 0.4753)
# ['arknights', 'vue', 'xlsx'] -> system (Similarity: 0.4082)
#   0%|          | 45/185876 [00:00<18:12, 170.16it/s]
# ['nodejs'] -> web-development (Similarity: 0.3863)
# ['asyncio', 'mysql', 'orm', 'peewee', 'postgresql', 'python'] -> system (Similarity: 0.4284)
# ['attack-defense-ctf', 'awd', 'awd-platform', 'cardinal', 'ctf', 'ctf-awd', 'ctf-awd-platform', 'ctf-platform', 'golang', 'lsif-enabled'] -> system (Similarity: 0.3525)
# ['css', 'css-in-js', 'preprocessor', 'style'] -> system (Similarity: 0.4505)
# ['icons', 'react', 'vue'] -> system (Similarity: 0.3384)
# ['create2', 'ethereum', 'factory', 'metamorphic', 'mutable', 'smart-contracts'] -> blockchain (Similarity: 0.6037)
# ['education', 'rust', 'video'] -> education (Similarity: 0.7246)
# ['captcha-solving', 'gan', 'generative-adversarial-network', 'keras', 'neural-network', 'simgan'] -> artificial-intelligence (Similarity: 0.4922)
# ['cryptocurrency', 'hft', 'high-frequency-trading', 'orderbook', 'trading'] -> blockchain (Similarity: 0.5472)
# ['3d', 'graphics', 'realism', 'shaders', 'threejs'] -> computer-vision (Similarity: 0.5436)
# ['antialiasing', 'global-illumination', 'raytracing', 'realism', 'threejs'] -> computer-vision (Similarity: 0.5452)
# ['3d', 'effects', 'graphics', 'interactive', 'threejs'] -> computer-vision (Similarity: 0.5159)
# ['0cch-windbg-extension', 'debugger', 'trace', 'windbg'] -> cybersecurity (Similarity: 0.2916)
# ['ctf', 'ctf-tools', 'framework', 'java', 'jython', 'kotlin-java', 'python', 'websecurity'] -> cybersecurity (Similarity: 0.4772)
# ['python', 'reverse-engineering'] -> artificial-intelligence (Similarity: 0.4781)
# ['ctf', 'generator', 'hacking', 'revshell', 'security', 'tryhackme'] -> cybersecurity (Similarity: 0.5479)
# ['discord', 'discord-rpc', 'rich-presence', 'wine'] -> artificial-intelligence (Similarity: 0.3703)
# ['gpt', 'nanogpt', 'transformers', 'webgpu'] -> system (Similarity: 0.3116)
# ['0install', 'cross-platform', 'decentralized', 'package-manager'] -> cloud-computing (Similarity: 0.4221)
# ['command-line', 'shell', 'tool', 'yaml'] -> system (Similarity: 0.4377)
# ['clash-for-windows', 'surge'] -> system (Similarity: 0.3668)
# ['css'] -> system (Similarity: 0.4102)
# ['emulator', 'nestopia', 'nintendo', 'nintendo-nes'] -> system (Similarity: 0.4224)
# ['betterdiscord', 'theme'] -> system (Similarity: 0.3770)
# ['head', 'html', 'react', 'react-hooks', 'seo'] -> web-development (Similarity: 0.3963)
# ['callbag', 'events', 'iterable', 'javascript', 'observable', 'stream', 'typescript'] -> system (Similarity: 0.4230)
# ['privacy', 'sms', 'telnyx', 'twilio', 'voip'] -> cybersecurity (Similarity: 0.3951)
# ['annotation', 'computer-vision', 'datasets-preparation', 'pytorch'] -> computer-vision (Similarity: 0.6986)
# ['blazefox', 'exploitation', 'firefox'] -> cybersecurity (Similarity: 0.3400)
# ['cve-2021-24086', 'fragmentation', 'ipv6', 'ipv6preassembledatagram', 'tcpip'] -> cybersecurity (Similarity: 0.3569)
# ['accept-encoding', 'cve-2021-31166', 'http', 'ulpparsecontentcoding'] -> education (Similarity: 0.3339)
# ['binary-exploitation', 'exploit-development', 'exploitation-framework', 'gadget', 'return-oriented-programming', 'rop', 'rop-chain', 'rop-gadgets'] -> system (Similarity: 0.4335)
# ['random', 'thrift-store'] -> artificial-intelligence (Similarity: 0.3000)
# ['bochs', 'bochscpu', 'code-coverage', 'fuzz-testing', 'fuzzer', 'fuzzing', 'kvm-api', 'security', 'snapshot-fuzzer', 'testing', 'winhv'] -> cybersecurity (Similarity: 0.4422)
# ['algorithm', 'bloom-filter', 'bplustree', 'dp', 'mysql', 'quick-sort', 'red-black-tree', 'rsa'] -> data-science (Similarity: 0.4725)
# ['agora', 'ffmpeg', 'janus', 'rtmp', 'rtp', 'rtsp', 'srs', 'webrtc', 'x264'] -> system (Similarity: 0.4234)
# ['acm', 'cpp', 'leetcode', 'mysql', 'nginx', 'os', 'redis'] -> system (Similarity: 0.5354)
# ['amazon', 'facebook', 'google', 'microsoft', 'paper', 'stanford', 'twitter'] -> education (Similarity: 0.5054)
# ['cpp', 'docker', 'etcd', 'fuse', 'hash', 'kafka', 'kernel', 'redis', 'virtio'] -> system (Similarity: 0.5415)
#   0%|          | 139/185876 [00:00<08:59, 344.43it/s]
# ['cpp', 'cpp11', 'cpp14', 'cpp17', 'cpp20', 'cpp98'] -> system (Similarity: 0.2950)
# ['boost', 'cpp', 'libevent', 'mongodb', 'nginx', 'ntyco', 'openmp'] -> blockchain (Similarity: 0.4307)
# ['c', 'dpdk', 'linux-kernel', 'openvswitch', 'vpp'] -> system (Similarity: 0.4717)
# ['c', 'ffmpeg', 'webrtc'] -> computer-vision (Similarity: 0.4131)
# ['cpu', 'high-performance', 'interview', 'mongodb', 'mysql', 'network', 'nginx', 'redis', 'storage', 'zookeeper'] -> system (Similarity: 0.5229)
# ['docker', 'go', 'golang', 'k8s', 'kubernetes'] -> system (Similarity: 0.4153)
# ['ceph', 'fuse', 'kvm', 'linux-kernel'] -> system (Similarity: 0.4750)
# ['c', 'kernel', 'linux', 'memory-management'] -> system (Similarity: 0.5660)
# ['ceph', 'ebpf', 'fuse', 'iouring', 'kvm', 'linux-kernel'] -> system (Similarity: 0.4440)
# ['cpp', 'kubernetes', 'linux', 'tcp-ip'] -> system (Similarity: 0.4427)
# ['cassandra', 'couchdb', 'mariadb', 'mongodb', 'mysql', 'oceanbase', 'percona-server', 'redis', 'rocksdb', 'tidb', 'tokudb'] -> data-science (Similarity: 0.4200)
# ['rust-language'] -> web-development (Similarity: 0.2356)
# ['bind', 'hacking', 'pentest', 'pop-shells', 'remote', 'reverse', 'shell'] -> system (Similarity: 0.4650)
# ['open-access', 'sci-hub', 'sci-hubextension', 'scihub', 'webextensions-api'] -> data-science (Similarity: 0.3135)
# ['fourier-analysis', 'image', 'image-analysis', 'image-processing', 'signal-processing'] -> computer-vision (Similarity: 0.7025)
# ['pentesting', 'post-exploitation', 'redteam'] -> education (Similarity: 0.3957)
# ['api-hooking', 'cpp', 'pentesting-windows', 'redteaming'] -> artificial-intelligence (Similarity: 0.3432)
# ['audio', 'audio-player', 'ios', 'ios-lib', 'ios-ui', 'objective-c', 'player', 'video'] -> computer-vision (Similarity: 0.4312)
# ['collaboration', 'cusomization', 'dns', 'integration', 'osint', 'paas', 'recon', 'scanner', 'security'] -> cybersecurity (Similarity: 0.5214)
# ['jammer', 'jamming', 'wifi'] -> cybersecurity (Similarity: 0.3011)
# ['adb', 'android', 'debloat', 'privacy'] -> system (Similarity: 0.3912)
# ['banking', 'builder', 'carbanak', 'code', 'malicious', 'malware', 'source'] -> cybersecurity (Similarity: 0.4996)
# ['bullshit', 'charlatan', 'cloud', 'cryptography', 'encryption', 'fernet', 'git', 'magic', 'password', 'password-manager', 'security'] -> cybersecurity (Similarity: 0.5280)
# ['botnet', 'ioc', 'ioc-development', 'iot', 'leak', 'linux', 'malware', 'malware-analysis', 'malware-development', 'malware-research', 'mirai', 'mirai-source'] -> cybersecurity (Similarity: 0.5994)
# ['fingerprint', 'hidden-services', 'scanner', 'shodan', 'ssh', 'tor'] -> cybersecurity (Similarity: 0.4947)
# ['console', 'debugger', 'hacktoberfest', 'ruby', 'ruby-debugger', 'syntax-highlighting', 'terminal', 'tty', 'visual'] -> system (Similarity: 0.4504)
# ['0x4447', '0x4447-product-s3-email', '0x4447-products', 'aws', 'aws-lambda', 'aws-s3', 'aws-ses', 'codepipeline', 'email', 'email-sender', 'free', 'free-email', 's3', 's3-bucket', 's3-email'] -> cloud-computing (Similarity: 0.4480)
# ['cnn', 'deep-learning', 'handwriting-recognition', 'machine-learning', 'rnn', 'tensorflow'] -> artificial-intelligence (Similarity: 0.6523)
# ['bot', 'bot-api', 'bot-framework', 'nest', 'nestjs', 'nodejs', 'telegraf', 'telegram', 'telegram-bot', 'telegram-bot-api', 'typescript'] -> artificial-intelligence (Similarity: 0.3514)
# ['awesome-list', 'offensive-security', 'oscp', 'oscp-prep', 'oscp-tools', 'penetration-testing', 'pentest', 'pentesting'] -> cybersecurity (Similarity: 0.4335)
# ['awesome', 'awesome-list', 'detection', 'incident-response', 'security', 'threat-detection', 'threat-hunting'] -> cybersecurity (Similarity: 0.5427)
# ['automation', 'burp', 'burpsuite', 'devops', 'python', 'security', 'security-automation', 'security-scanner', 'security-tools', 'web-security'] -> cybersecurity (Similarity: 0.6804)
# ['fingerprinting', 'honeypot', 'metadata', 'network', 'python', 'quic', 'rdp', 'security', 'ssh', 'threat-hunting', 'tls', 'tshark'] -> cybersecurity (Similarity: 0.5922)
# ['client', 'csharp', 'developer-tools', 'fluent', 'fluenthub', 'github', 'github-api', 'graphql', 'hacktoberfest', 'mica', 'mit-license', 'modern', 'oauth', 'power-user', 'powerful', 'uwp', 'windows', 'windows-11', 'winui', 'xaml'] -> system (Similarity: 0.4527)
# ['alipay', 'alipaysdk', 'android', 'ios', 'react-native', 'sdk'] -> blockchain (Similarity: 0.3347)
# ['electron', 'electron-vibrancy', 'vibrancy'] -> computer-vision (Similarity: 0.2357)
# ['ai', 'chat', 'chatgpt', 'docker', 'openai', 'proxy', 'rust', 'server'] -> system (Similarity: 0.4762)
# ['alpine', 'docker', 'glibc', 'lede', 'libc', 'linux', 'musl', 'nas', 'openwrt', 'rust', 'spk', 'syno', 'synology', 'xunlei'] -> system (Similarity: 0.5009)
# ['cobaltstrike-cna', 'readteaming', 'redteam'] -> system (Similarity: 0.3327)
# ['fingerprinting', 'nuclei-templates', 'wappalyzer', 'whatweb'] -> computer-vision (Similarity: 0.3567)
# ['exp', 'exploit', 'spring', 'springboot', 'vul', 'vulnerability'] -> system (Similarity: 0.4830)
# ['app', 'diff-viewer', 'fluent', 'markdown', 'notepad', 'texteditor', 'uwp', 'windows'] -> system (Similarity: 0.4048)
# ['game', 'pal3', 'pal3a', 'rpg', 'rpg-game', 'unity', 'unity3d'] -> system (Similarity: 0.4998)
# ['access', 'bypass', 'elevate', 'go', 'golang', 'uac', 'uacbypass', 'windows'] -> system (Similarity: 0.4626)
# ['fuzzing', 'hacking-tools', 'normalization', 'regex', 'waf-bypass'] -> cybersecurity (Similarity: 0.4202)
# ['asp-net', 'hacking-tools', 'viewstate'] -> cybersecurity (Similarity: 0.4482)
# ['bash', 'chatbot', 'chatgpt', 'chatgpt-api', 'chatgpt-api-wrapper', 'cli', 'dall-e', 'dalle', 'dalle2', 'image-generation', 'shell', 'shell-script', 'terminal', 'zsh'] -> system (Similarity: 0.3795)
# ['ethereum', 'mev', 'rust', 'solidity'] -> blockchain (Similarity: 0.5250)
#   0%|          | 281/185876 [00:00<07:18, 423.11it/s]
# ['linux', 'linux-insides', 'linux-kernel'] -> system (Similarity: 0.4288)
# ['binary', 'ctf', 'ctf-tools', 'database', 'exploitation', 'libc', 'libc-database', 'libc-db', 'libcdb', 'pwn', 'reverse-engineering', 'wargame'] -> data-science (Similarity: 0.4853)
# ['ctf', 'ctf-tools', 'exploitation', 'ghidra', 'ghidra-scripts', 'pwn', 'reverse-engineering'] -> cybersecurity (Similarity: 0.4374)
# ['boilerplate', 'cqrs', 'ddd', 'eventsourcing', 'eventstore', 'graphql', 'hacktoberfest', 'microservice', 'nestjs', 'nodejs', 'saga', 'typescript'] -> web-development (Similarity: 0.4259)
# ['binary-exploitation', 'php-internals', 'zend-engine'] -> system (Similarity: 0.3317)
# ['attack-surface-management', 'biu', 'biu-asm', 'easm', 'security'] -> cybersecurity (Similarity: 0.5581)
# ['github', 'leakage', 'security'] -> cybersecurity (Similarity: 0.5348)
# ['autoscan', 'scanner', 'security', 'security-audit', 'security-vulnerability', 'sqlmap', 'sqlmap-webui', 'sqlmapapi'] -> cybersecurity (Similarity: 0.5043)
# ['adobe-photoshop', 'av1', 'av1-image', 'avif', 'cpp'] -> computer-vision (Similarity: 0.4255)
# ['awesome', 'awesome-list', 'oracle-manipulation', 'security', 'solidity', 'web3'] -> system (Similarity: 0.5321)
# ['c-plus-plus', 'emulator', 'game-engine', 'lua', 'pico-8', 'pico8'] -> system (Similarity: 0.4420)
# ['player', 'video', 'youtube'] -> education (Similarity: 0.3934)
# ['xcode', 'xcodeproj'] -> cybersecurity (Similarity: 0.2327)
# ['bypass', 'dhl', 'gh0st', 'gui', 'hack', 'pentest', 'rat', 'shellcode'] -> system (Similarity: 0.5056)
# ['blueteam', 'malware', 'malware-detection', 'malware-research', 'osint', 'phishing', 'phishing-attacks', 'phishing-detection', 'phishing-sites'] -> cybersecurity (Similarity: 0.6009)
# ['aix', 'buffer-overflow', 'exploits', 'linux', 'mysql', 'openbsd', 'oracle', 'solaris', 'zyxel'] -> system (Similarity: 0.5336)
# ['android', 'frida', 'ios', 'mobile', 'reverse-engineering'] -> artificial-intelligence (Similarity: 0.3840)
# ['code-review', 'semgrep', 'semgrep-rules', 'static-analysis', 'vulnerability-research'] -> cybersecurity (Similarity: 0.4148)
# ['active-directory', 'brute-force', 'information-gathering', 'metasploit-framework', 'penetration-testing'] -> artificial-intelligence (Similarity: 0.4731)
# ['pentesting', 'recon', 'security-tools', 'whitehat'] -> cybersecurity (Similarity: 0.4950)
# ['frontpage', 'hack', 'pentest', 'sharepoint', 'sparty'] -> system (Similarity: 0.4682)
# ['api', 'baidu-image', 'cdnjs', 'element-ui', 'go', 'golang', 'image-store', 'mdui', 'rest-api', 'vue', 'weibo-image'] -> cloud-computing (Similarity: 0.4022)
# ['avalanche', 'awesome-list', 'crypto', 'ethereum', 'mev', 'mev-research', 'miner-extracted-value', 'solana'] -> blockchain (Similarity: 0.4863)
# ['ad-blocker', 'adblock', 'adblocker', 'dns', 'dns-over-https', 'dns-server', 'golang', 'parental-control', 'pihole', 'self-hosted', 'selfhosted'] -> blockchain (Similarity: 0.4026)
# ['bug-bounty', 'bug-hunting', 'cybersecurity', 'ejpt', 'ethical-hacking', 'exploit', 'hacker', 'hacking', 'hackthebox', 'infosec', 'kali', 'oscp', 'owasp', 'penetration-testing', 'pentesting', 'pentesting-tools', 'pts', 'security', 'security-tools', 'vulnerabilities'] -> cybersecurity (Similarity: 0.6662)
# ['git', 'markdown', 'note', 'notebook', 'notebooks', 'notes'] -> system (Similarity: 0.4235)
# ['bug-bounty', 'dumpall', 'githack', 'hacking', 'pentesting', 'python3', 'scanner', 'security', 'spider', 'svn', 'tools'] -> cybersecurity (Similarity: 0.5650)
# ['auctions', 'marketplace', 'nft', 'nft-gallery', 'nft-marketplace', 'nftools', 'nfts', 'plugin', 'woocommerce', 'woocommerce-auction', 'woocommerce-plugin', 'woocommerce-shop', 'zora'] -> blockchain (Similarity: 0.4208)
# ['android', 'android-animation', 'animation', 'rxjava'] -> computer-vision (Similarity: 0.3843)
# ['cve-2021-44228', 'internet-scanning', 'log4j', 'rce-scanner', 'vulnerability-scanners'] -> cybersecurity (Similarity: 0.4599)
# ['enumeration', 'exploitation', 'footprinting', 'intelligence-gathering', 'osint', 'reconnaissance', 'scanning-enumeration', 'tidos-framework', 'vulnerability-analysis', 'vulnerability-detection', 'web-application-security', 'web-fuzzer', 'web-penetration-testing'] -> cybersecurity (Similarity: 0.5197)
# ['audit', 'crafted-tokens', 'crawler', 'csrf', 'csrf-attacks', 'csrf-poc', 'csrf-scanner', 'csrf-tokens', 'spider', 'token-generation', 'xsrf'] -> cybersecurity (Similarity: 0.4387)
# ['awesome', 'awesome-list', 'ethereum', 'ethereum-blockchain', 'gas-optimization', 'linter-solidity', 'polygon', 'resources', 'smart-contracts', 'smart-contracts-audit', 'solidity', 'solidity-compiler', 'solidity-contracts', 'solidity-dapps', 'solidity-language', 'solidity-parser', 'solidity-security', 'web3-dapp'] -> blockchain (Similarity: 0.5775)
# ['malware', 'meterpreter', 'python', 'rat', 'security'] -> cybersecurity (Similarity: 0.5866)
# ['chatgpt-app', 'cron', 'go', 'letsencrypt', 'nginx', 'self-hosted', 'vue', 'webui'] -> blockchain (Similarity: 0.4078)
# ['aliexpress', 'cheap', 'china', 'electronics', 'general-electronics', 'starterkit'] -> system (Similarity: 0.4438)
# ['awesome', 'awesome-list', 'lens', 'lens-protocol', 'lensprotocol'] -> computer-vision (Similarity: 0.4417)
# ['arbitrum', 'auditing', 'base', 'bsc', 'ethereum', 'moonbeam', 'optimism', 'polygon', 'solidity', 'zksync'] -> blockchain (Similarity: 0.5802)
# ['chatgpt', 'gpt-3-5', 'gpt-4', 'jailbreak', 'openai', 'prompt'] -> system (Similarity: 0.3625)
# ['fuzzing-templates', 'gauplus', 'hakrawler', 'katana', 'nuclei', 'nuclei-templates', 'nucleifuzzer', 'paramspider', 'uro', 'waybackurls'] -> system (Similarity: 0.3975)
# ['bypass', 'bypass-uac', 'bypassuac', 'red-team', 'uac', 'windows'] -> system (Similarity: 0.4588)
# ['cgpwn', 'ctf-tools', 'symbolic-execution', 'vagrant', 'vm'] -> system (Similarity: 0.3612)
# ['ios', 'ios-security'] -> cybersecurity (Similarity: 0.3405)
# ['bash', 'macos', 'macos-catalina', 'security-tools'] -> system (Similarity: 0.4458)
# ['bug', 'bugbounty', 'bugbounty-checklist', 'bugbounty-reports', 'bugbounty-tool', 'bugbountytips', 'bugbountytricks', 'bugcrowd', 'bugs', 'ethical-hacker', 'ethical-hacking', 'hackerone', 'red-team', 'red-teaming', 'vulnerabilities', 'vulnerability'] -> cybersecurity (Similarity: 0.4716)
# ['cli', 'gist', 'oclif', 'typescript'] -> system (Similarity: 0.3723)
# ['blockchain', 'security'] -> blockchain (Similarity: 0.8217)
# ['card', 'cards', 'feed', 'milestones', 'timeline'] -> system (Similarity: 0.4705)
# ['anti-analysis', 'anti-debugging', 'antianalysis', 'antidebug', 'antidebugging', 'debugging', 'dynamic-analysis', 'obfuscation', 'rust', 'static-analysis'] -> data-science (Similarity: 0.3787)
#   0%|          | 324/185876 [00:00<07:43, 400.12it/s]
# ['cfmm', 'mathematics', 'mev', 'research', 'resources', 'smt', 'solidity'] -> data-science (Similarity: 0.5596)
# ['amm', 'awesome-list'] -> artificial-intelligence (Similarity: 0.3006)
# ['awesome-list', 'derivatives'] -> artificial-intelligence (Similarity: 0.2693)
# ['blockchain', 'ethereum', 'protocol'] -> blockchain (Similarity: 0.8425)
# ['css', 'demo', 'geeks', 'hackers', 'html', 'javascript', 'portfolio', 'portfolio-template', 'programmer', 'resume', 'website'] -> web-development (Similarity: 0.5088)
# ['deprecated'] -> education (Similarity: 0.2878)
# ['0x', 'ethereum'] -> blockchain (Similarity: 0.5548)
# ['0x', 'dapp', 'ethereum', 'golang', 'libp2p', 'webassembly', 'webrtc'] -> blockchain (Similarity: 0.4827)
# ['0x', 'erc20', 'erc721', 'ethereum', 'exchange'] -> system (Similarity: 0.5021)
# ['bruteforce', 'bugbounty', 'dirsearch', 'ffuf', 'fuzz', 'fuzz4bounty', 'wordlist'] -> system (Similarity: 0.3648)
# ['bug-bounty', 'bugbounty', 'enumeration', 'onliner-scripts', 'subdomain-enumeration'] -> system (Similarity: 0.3078)
# ['graphql', 'graphql-federation'] -> data-science (Similarity: 0.2431)
# ['bugbounty', 'checklist', 'owasp', 'security', 'security-tools', 'security-vulnerability', 'testing'] -> cybersecurity (Similarity: 0.6150)
# ['detection-engineering', 'dfir', 'threat-hunting'] -> cybersecurity (Similarity: 0.5223)
# ['dfir', 'edr', 'ids', 'sysmon', 'threat-hunting', 'windows'] -> system (Similarity: 0.5276)
# ['ctf', 'ctf-tools', 'debugging', 'docker', 'exploit', 'exploit-development', 'gdb', 'kernel', 'linux', 'linux-kernel', 'pwn', 'qemu'] -> system (Similarity: 0.5265)
# ['directed-fuzzing', 'embedded', 'exploitation', 'fuzzing', 'fuzzing-binaries', 'guided-fuzzing', 'hybrid-fuzzing', 'iot', 'kernel', 'linux', 'linux-kernel', 'mitigations', 'paper', 'rca', 'root-cause', 'sanitizer', 'vulnerability-detection'] -> system (Similarity: 0.5117)
# ['hacktoberfest', 'hacktoberfest2021', 'python', 'python3', 'trading', 'tradingview', 'view'] -> cybersecurity (Similarity: 0.4341)
# ['blockchain', 'blockchain-demos', 'blockchain-technology', 'cryptocurrencies', 'cryptocurrency', 'javascript', 'nodejs'] -> blockchain (Similarity: 0.8793)
# ['blockchain', 'cryptography', 'javascript'] -> blockchain (Similarity: 0.7876)
# ['hacking-tool', 'network-security', 'pentest-scripts', 'pentest-tool', 'pentesting', 'pentesting-networks', 'ruby', 'security-automation', 'security-scanner', 'security-tools'] -> cybersecurity (Similarity: 0.5657)
# ['erc1155', 'ethereum', 'nft', 'semi-fungible', 'sft', 'token-contract'] -> blockchain (Similarity: 0.5461)
# ['erc20', 'ethereum', 'meta-transaction-functionality'] -> blockchain (Similarity: 0.5465)
# ['erc-1155', 'ethereum', 'swap'] -> blockchain (Similarity: 0.5062)
# ['amazon', 'bugbounty', 'cloud', 'cloud-security', 'cloud-storage', 'digitalocean', 'google', 'hacking', 'infosec', 'linode', 'pentest-tool', 'pentesting', 'redteam', 's3-bucket', 'vultr'] -> cloud-computing (Similarity: 0.6009)
# ['bugbounty', 'endpoint-discovery', 'linkextractor', 'pentest-tool', 'pentesting', 'pentesting-tools'] -> data-science (Similarity: 0.3533)
# ['c-plus-plus', 'connection-pool', 'cpp', 'data-slice-storage', 'multi-platform', 'redis', 'redis-client', 'redis-cluster', 'rediscluster', 'thread-safe', 'xredis'] -> cloud-computing (Similarity: 0.4607)
# ['exploit', 'fuzzing', 'payloads', 'pentesting', 'reconnaissance', 'regex', 'tracking', 'web-security', 'xss'] -> cybersecurity (Similarity: 0.5385)
# ['bypass-antivirus', 'bypass-edr', 'evasion', 'redteam-tools'] -> cybersecurity (Similarity: 0.3805)
# ['blockchain', 'starknet'] -> blockchain (Similarity: 0.7907)
# ['blockchain', 'hardhat', 'starknet'] -> blockchain (Similarity: 0.6935)
# ['enumeration', 'persistence', 'privelage-escalation'] -> artificial-intelligence (Similarity: 0.4176)
# ['capture-the-flag', 'ctf', 'cybersecurity', 'handbooks', 'infosec', 'offensive', 'offensive-security', 'penetration-testing', 'pentesting', 'red-teaming', 'security'] -> cybersecurity (Similarity: 0.6836)
# ['design', 'font', 'programming-font', 'typeface'] -> system (Similarity: 0.3477)
# ['nodejs', 'tidal', 'tidalapi'] -> blockchain (Similarity: 0.3924)
# ['csharp', 'exploit', 'silent', 'uac', 'uac-authorization', 'uac-bypass', 'uacbypass', 'windows'] -> cybersecurity (Similarity: 0.4451)
# ['enumeration', 'password-spray', 'pentest', 'pentesting-tools', 'python', 'python3', 'security', 'security-tools'] -> cybersecurity (Similarity: 0.5437)
# ['css', 'html-slide-template', 'markdown-html-remarkjs', 'remarkjs'] -> web-development (Similarity: 0.3043)
# ['artificial-neural-networks', 'blas', 'c', 'c99', 'cblas', 'classification', 'continuous-integration', 'efficient', 'embedded', 'feedforward-neural-network', 'header-only', 'machine-learning', 'matrix', 'neural-network', 'portable', 'regression', 'travis-ci', 'vectorization'] -> artificial-intelligence (Similarity: 0.6559)
# ['algorithm', 'artificial-intelligence', 'continuous-optimization', 'discrete-optimization', 'evolutionary-algorithm', 'genetic-algorithm', 'genetic-algorithm-framework', 'harmony-search', 'hill-climbing', 'library', 'machine-learning', 'machine-learning-algorithms', 'metaheuristics', 'optimization', 'optimization-algorithms', 'particle-swarm-optimization', 'python', 'simulated-annealing', 'stochastic-optimizers', 'tabu-search'] -> artificial-intelligence (Similarity: 0.6773)
# ['css', 'flexbox', 'grid', 'grid-layout'] -> system (Similarity: 0.3960)
# ['gif', 'grunt', 'image', 'jpeg', 'optimization', 'png'] -> computer-vision (Similarity: 0.5383)
# ['gif', 'gulp', 'image', 'jpeg', 'optimization', 'png'] -> computer-vision (Similarity: 0.5433)
# ['image', 'lazyload', 'web-components'] -> computer-vision (Similarity: 0.4603)
# ['component', 'component-library', 'demo', 'design', 'javascript', 'mobile', 'react-components', 'react-hooks', 'reactjs', 'typescript'] -> system (Similarity: 0.3850)
# ['do-not-use-in-production', 'just-for-learn', 'poc'] -> education (Similarity: 0.3783)
# ['agents', 'ai', 'autogpt', 'gpt-4'] -> artificial-intelligence (Similarity: 0.5899)
#   0%|          | 418/185876 [00:01<07:11, 429.59it/s]
# ['django', 'django-admin', 'django-api', 'django-application', 'django-apps', 'django-rest', 'django-rest-framework', 'django-user', 'django-user-management', 'django2', 'hacktoberfest', 'otp', 'otp-verification', 'python', 'registration-system', 'rest-api', 'signup-flow', 'user-management'] -> blockchain (Similarity: 0.2842)
# ['ant-design-vue', 'codegenerator', 'composition-api', 'element-plus', 'element-ui', 'java', 'low-code', 'smart', 'spring-boot', 'spring-cloud', 'springboot', 'typescript', 'vue', 'vue3'] -> system (Similarity: 0.4508)
# ['chai', 'circleci', 'cypress', 'docker', 'emberjs', 'hacktoberfest', 'hapijs', 'knexjs', 'mocha', 'nock', 'nodejs', 'npm', 'postgresql', 'scalingo', 'sinonjs'] -> system (Similarity: 0.4198)
# ['glcm', 'histogram', 'image', 'image-processing', 'lbp', 'py-lbp', 'python', 'python-glcm-lbp', 'rgb', 'rgb-histogram'] -> computer-vision (Similarity: 0.5623)
# ['beego', 'redis', 'rpcx', 'shiro'] -> system (Similarity: 0.4007)
# ['prometheus-chinese', 'prometheus-cn', 'user-manual'] -> artificial-intelligence (Similarity: 0.3646)
# ['pyqt5', 'python3', 'spider', 'wechat', 'wechat-article'] -> system (Similarity: 0.3739)
# ['android-development', 'android-topactivity'] -> web-development (Similarity: 0.1983)
# ['android', 'android-library', 'bottombar', 'bottomnavigation', 'bottomnavigationbar', 'bottomnavigationview'] -> computer-vision (Similarity: 0.2348)
# ['github-actions', 'hacktoberfest', 'wordpress', 'wordpress-deployment'] -> web-development (Similarity: 0.4152)
# ['ai', 'artificial-intelligence', 'azure', 'classification', 'computer-vision', 'content-tagging', 'hacktoberfest', 'ibm-watson', 'language-processing', 'machine-learning', 'microsoft-azure', 'ml', 'wordpress', 'wordpress-plugin'] -> artificial-intelligence (Similarity: 0.7433)
# ['content', 'content-distribution-network', 'content-distributor', 'content-management', 'distribution', 'hacktoberfest', 'management', 'syndication', 'wordpress'] -> education (Similarity: 0.4398)
# ['elasticsearch', 'hacktoberfest', 'search', 'wordpress', 'wordpress-plugin', 'wp-query'] -> web-development (Similarity: 0.3639)
# ['limited', 'privacy', 'restrict', 'restricted', 'wordpress'] -> system (Similarity: 0.3756)
# ['file', 'graphic', 'hacktoberfest', 'image', 'media', 'mime', 'sanitize', 'security', 'svg', 'svg-upload', 'upload', 'vector', 'wordpress'] -> computer-vision (Similarity: 0.5109)
# ['mockups', 'sketch-template', 'wordpress', 'wordpress-admin-mockups'] -> web-development (Similarity: 0.4378)
# ['hammer', 'wordpress', 'wp-ha'] -> system (Similarity: 0.4043)
# ['archived'] -> system (Similarity: 0.2859)
# ['mockery', 'mocking-library', 'monkey-patching', 'patchwork', 'phpunit', 'testing-library', 'unit-testing', 'wordpress'] -> system (Similarity: 0.3577)
# ['mysql', 'php', 'sharding'] -> blockchain (Similarity: 0.3842)
# ['html5', 'javascript', 'osu', 'pixi', 'rhythm-game', 'webgl-game'] -> web-development (Similarity: 0.4338)
# ['arouter', 'jetpack', 'rxjava'] -> system (Similarity: 0.3345)
# ['eleventy', 'eleventy-sample'] -> system (Similarity: 0.2662)
# ['eleventy', 'eleventy-api'] -> system (Similarity: 0.2709)
# ['blog', 'eleventy', 'eleventy-sample'] -> system (Similarity: 0.3500)
# ['eleventy', 'eleventy-utility'] -> system (Similarity: 0.3215)
# ['eleventy', 'eleventy-plugin', 'vue', 'vuejs'] -> system (Similarity: 0.3670)
# ['blog-engine', 'documentation-tool', 'eleventy', 'javascript', 'static-site-generator', 'templates'] -> web-development (Similarity: 0.5247)
# ['javascript', 'nodejs', 'repl', 'terminal'] -> web-development (Similarity: 0.4214)
# ['circular-references', 'javascript', 'json', 'json-dry', 'json-parser', 'json-serialization'] -> data-science (Similarity: 0.3232)
# ['computer-vision', 'deep-taylor-decomposition', 'interpretable-deep-learning', 'lrp', 'sensitivity-analysis', 'tensorflow', 'tutorial'] -> computer-vision (Similarity: 0.6515)
# ['alert', 'alertcontroller', 'alertview'] -> cybersecurity (Similarity: 0.3191)
# ['attributedlabel', 'coretext', 'ios', 'label', 'objective-c', 'tyattributedlabel'] -> computer-vision (Similarity: 0.3742)
# ['pager', 'pager-controller'] -> system (Similarity: 0.1704)
# ['graphsdk', 'microsoft365', 'microsoftgraph', 'powershell'] -> cloud-computing (Similarity: 0.3497)
# ['broadway', 'canvas', 'h264', 'html5', 'raspberry-pi', 'raspicam', 'video'] -> computer-vision (Similarity: 0.4763)
# ['colormaps', 'data-visualization', 'matplotlib', 'plotting', 'python', 'utility-functions'] -> data-science (Similarity: 0.4707)
# ['elastic', 'elastic-sql-dsl', 'elasticsearch', 'elasticsearch-gui', 'elasticview', 'es', 'go', 'sql', 'vue'] -> data-science (Similarity: 0.3234)
# ['mvvm', 'tool', 'windows', 'wpf'] -> system (Similarity: 0.4771)
# ['dora', 'dora-rpc', 'php', 'rpc', 'service-discovery', 'swoole', 'tcp'] -> cybersecurity (Similarity: 0.4337)
# ['anime', 'animegirl', 'doki-doki-literature-club', 'fate-grand-order', 'fate-stay-night', 'fateseries', 'grub', 'grub-boot-menu', 'grub-configuration', 'grub-themes', 'grub2', 'grub2-theme', 'hololive', 'hoshimachi-suisei', 'kobo-kanaeru', 'lycoris-recoil', 'theme', 'thequintessentialquintuplets', 'touhou-games', 'vtubers'] -> system (Similarity: 0.4347)
# ['color-emoji', 'color-font', 'emoji', 'font', 'linux', 'monospace-font', 'opentype-svg-fonts', 'svginot', 'twitter-emoji'] -> system (Similarity: 0.3382)
# ['adb', 'cmd', 'python3', 'twilio-sms-api'] -> artificial-intelligence (Similarity: 0.3591)
# ['11408', '211', '408', '985', 'cs', 'kaoyan', 'kaoyancs', 'network'] -> system (Similarity: 0.4436)
# ['lenis', 'react-three-fiber', 'smoothscroll'] -> computer-vision (Similarity: 0.3003)
# ['aria2', 'macos', 'menubar', 'osx', 'swift'] -> system (Similarity: 0.3901)
#   0%|          | 538/185876 [00:01<06:05, 507.00it/s]
# ['es6', 'javascript', 'tutorial'] -> web-development (Similarity: 0.4302)
# ['2d-game-framework', 'game-development', 'game-engine', 'game-frameworks', 'gamedev', 'rust'] -> web-development (Similarity: 0.4217)
# ['irt', 'psychometrics', 'python'] -> artificial-intelligence (Similarity: 0.4902)
# ['android', 'call', 'car', 'didi', 'java', 'map', 'mobile', 'nfc', 'ocr', 'rfid', 'uber'] -> system (Similarity: 0.4883)
# ['frontend', 'javascript', 'library', 'web', 'webdev'] -> web-development (Similarity: 0.6867)
# ['a11y', 'accessibility', 'best-practices'] -> computer-vision (Similarity: 0.3769)
# ['analytics', 'analytics-dashboard', 'dap', 'statistics', 'traffic'] -> data-science (Similarity: 0.5500)
# ['18f', 'css', 'frontend', 'guide', 'guild', 'html', 'javascript'] -> web-development (Similarity: 0.4866)
# ['civic-tech', 'identity', 'identity-provider', 'oidc', 'rails'] -> system (Similarity: 0.4442)
# ['cropper', 'image', 'imagecropper', 'mpvue', 'shear', 'uni-app', 'wechat', 'wepy'] -> computer-vision (Similarity: 0.5013)
# ['h5', 'mpvue', 'uniapp', 'vue', 'wepy'] -> artificial-intelligence (Similarity: 0.4104)
# ['doodle', 'draw', 'edit', 'graffit', 'handwrite', 'paint', 'painter', 'picture'] -> computer-vision (Similarity: 0.4291)
# ['java', 'mybatis', 'spring'] -> system (Similarity: 0.4063)
# ['chrome', 'chrome-extension', 'google-chrome', 'javascript', 'keybindings', 'keyboard', 'keyboard-shortcuts', 'productivity', 'vim'] -> web-development (Similarity: 0.3942)
# ['github', 'github-for-everyone', 'iran', 'iranian', 'sanction', 'sanctions'] -> education (Similarity: 0.3690)
# ['3d-face-alignment', 'dense-facial-landmarks', 'face-alignment', 'face-reconstruction', 'head-pose-estimation', 'headpose-estimation'] -> computer-vision (Similarity: 0.5077)
# ['face-alignment', 'face-detection', 'head-pose-estimation', 'tflite', 'vtuber'] -> computer-vision (Similarity: 0.5968)
# ['activitykit', 'dynamic-island', 'ios', 'ios16', 'live-activities', 'swift', 'swift5', 'swiftui'] -> system (Similarity: 0.3352)
# ['xposed'] -> cybersecurity (Similarity: 0.3085)
# ['3d-face-alignment', 'computer-vision', 'deeplearning', 'face-alignment', 'torch7'] -> computer-vision (Similarity: 0.7001)
# ['binary-convolutions', 'computer-vision', 'convolutional-neural-networks', 'deep-learning', 'face-alignment', 'torch7'] -> computer-vision (Similarity: 0.7415)
# ['binary', 'computer-vision', 'deep-learning', 'human-pose-estimation', 'network-binarization', 'torch7'] -> computer-vision (Similarity: 0.7489)
# ['cloudfirestore', 'firebase', 'firebase-firestore', 'firebase-storage', 'gcp', 'swift'] -> cloud-computing (Similarity: 0.4374)
# ['cloud-firestore', 'firebase', 'firebase-realtime-database', 'firebase-storage', 'firestore', 'swift'] -> cloud-computing (Similarity: 0.3801)
# ['ios', 'photos', 'sumo', 'swift'] -> computer-vision (Similarity: 0.4373)
# ['autolayout', 'inputbar', 'ios', 'swift', 'toolbar'] -> computer-vision (Similarity: 0.3203)
# ['arch', 'customization', 'dotfiles', 'eww', 'eww-config', 'gnome', 'hacktoberfest', 'hyprland', 'linux', 'neovim', 'neovim-configuration', 'rice', 'rofi', 'shell', 'starship-prompt', 'theme', 'unix', 'unixporn', 'waybar', 'wayland'] -> system (Similarity: 0.5150)
# ['angular2', 'go', 'golang', 'microservices', 'mysql', 'paas', 'redis', 'typescript'] -> system (Similarity: 0.4334)
# ['framework', 'helper', 'love2d', 'lua', 'lua-library'] -> system (Similarity: 0.4358)
# ['1c-edt', '1c-enterprise', 'convert', 'converter', 'edt', 'git', 'gitsync', 'repository', 'sync', 'synchronization', 'synchronizer'] -> system (Similarity: 0.4855)
# ['1c-enterprise', 'hacktoberfest'] -> cybersecurity (Similarity: 0.4291)
# ['bsl-language-server', 'hacktoberfest', 'sonar-communitybsl-plugin', 'sonarqube'] -> web-development (Similarity: 0.3283)
# ['china', 'indie', 'indie-developer'] -> education (Similarity: 0.4097)
# ['computer-science', 'crash-course', 'cs'] -> data-science (Similarity: 0.5773)
# ['ass', 'captions', 'desktop-app', 'electron', 'srt', 'subtitle', 'vtt', 'vuejs'] -> system (Similarity: 0.4871)
# ['subtitle', 'tampermonkey', 'youtube', 'youtube-subtitle-downloader'] -> artificial-intelligence (Similarity: 0.2994)
# ['apache-arrow', 'apache-mesos', 'apache-spark', 'artificial-intelligence', 'awesome-list', 'deep-learning', 'deep-learning-framework', 'federated-learning', 'knowledge-distillation', 'kubernetes', 'machine-learning', 'machine-learning-systems', 'model-compression', 'pruning', 'quantization'] -> artificial-intelligence (Similarity: 0.7070)
# ['artwork', 'colorart', 'design', 'dribbble', 'dribbble-client', 'ios'] -> computer-vision (Similarity: 0.4290)
# ['ios', 'photobrowser', 'picture-viewer', 'picturebrowser'] -> computer-vision (Similarity: 0.4773)
# ['1f408', 'blog-engine', 'documentation', 'go', 'markdown', 'pages', 'server-rendering', 'static-site-generator', 'webapp', 'website-generator'] -> web-development (Similarity: 0.5866)
# ['supreme', 'supreme-bot', 'supremewebstore'] -> cybersecurity (Similarity: 0.2869)
# ['android-tv', 'anexplorer', 'chromebook', 'chromecast', 'file-explorer', 'fileexplorer', 'filemanager', 'ftp-client', 'ftpd-server', 'material', 'phone-storage', 'root', 'storage', 'storage-provider', 'text-editor', 'usb-devices', 'usb-otg', 'watchapp', 'wear-os'] -> cloud-computing (Similarity: 0.4007)
# ['bugbounty', 'information-gathering', 'information-security', 'osint', 'security-tools'] -> cybersecurity (Similarity: 0.5929)
# ['beian', 'bugbounty', 'domain', 'icp', 'information-gathering', 'information-security', 'osint', 'osint-tool', 'osint-tools', 'pentest-tool', 'python', 'python3', 'security-tools'] -> cybersecurity (Similarity: 0.5048)
# ['bot', 'spam-protection', 'telegram', 'telegram-bot'] -> cybersecurity (Similarity: 0.3954)
# ['ethereum-contract', 'price-oracle'] -> blockchain (Similarity: 0.4251)
# ['classic', 'desktop', 'emulator', 'html', 'javascript', 'operating-system', 'os', 'remake', 'retro', 'web-desktop', 'windows', 'windows-95', 'windows-98'] -> system (Similarity: 0.5513)
#   0%|          | 634/185876 [00:01<07:15, 425.28it/s]
# ['app', 'editor', 'guitar', 'html5', 'javascript', 'midi', 'music', 'scales', 'synth', 'synthesizer', 'tablature', 'tablature-parser', 'tabs', 'toy', 'tuna', 'web-app'] -> system (Similarity: 0.4514)
# ['app', 'canvas', 'drawing', 'editor', 'html5', 'image', 'image-editing', 'image-editor', 'image-manipulation', 'javascript', 'jspaint', 'ms-paint', 'mspaint', 'online', 'paint', 'painting', 'remake', 'retro', 'web-app', 'web-application'] -> computer-vision (Similarity: 0.5205)
# ['cli', 'command', 'command-history', 'command-line', 'command-line-app', 'console', 'console-substitute', 'html', 'html5', 'javascript', 'log', 'web'] -> web-development (Similarity: 0.4572)
# ['ansi-art', 'ansi-editor', 'artscene', 'ascii-art', 'bbs', 'drawing', 'image', 'image-editor', 'irc', 'mirc', 'mspaint', 'paint', 'pixel-art', 'pixel-editor', 'terminal', 'text-art', 'textual', 'tui'] -> computer-vision (Similarity: 0.5281)
# ['openrazer', 'razer', 'razer-macos'] -> system (Similarity: 0.3354)
# ['beta-vae', 'celeba', 'chairs-dataset', 'disentangled-representations', 'dsprites', 'unsupervised-learning', 'vae'] -> artificial-intelligence (Similarity: 0.4831)
# ['beta-vae', 'celeba', 'chairs-dataset', 'disentangled-representations', 'dsprites', 'factor-vae', 'factorvae', 'unsupervised-learning', 'vae'] -> artificial-intelligence (Similarity: 0.4421)
# ['adversarial-attacks', 'adversarial-example', 'machine-learning-security'] -> artificial-intelligence (Similarity: 0.4016)
# ['cnn-visualization', 'gradcam', 'gradcam-plus-plus', 'interpretable-deep-learning'] -> computer-vision (Similarity: 0.5121)
# ['classification', 'deep-learning', 'information-bottleneck', 'machine-learning', 'pytorch', 'variational-inference'] -> artificial-intelligence (Similarity: 0.6793)
# ['binance', 'go', 'nft'] -> computer-vision (Similarity: 0.3456)
# ['javascript', 'js', 'todomvc', 'vanilla-javascript', 'vanilla-js', 'vanillajs'] -> web-development (Similarity: 0.4280)
# ['active', 'application', 'automated', 'bugbounty', 'csrf', 'fuzzer', 'lfi', 'osint', 'owasp', 'passive', 'python', 'rce', 'rfi', 'scan', 'scanner', 'spider', 'sqli', 'vulnerability', 'web', 'xss'] -> system (Similarity: 0.5493)
# ['brute', 'brute-force', 'bruteforce', 'bruteforce-attacks', 'bruteforcing', 'bugbounty', 'hacking'] -> cybersecurity (Similarity: 0.4204)
# ['bugbounty', 'exploitdb', 'exploits', 'find', 'hackers', 'metasploit', 'nmap', 'pentest', 'search'] -> cybersecurity (Similarity: 0.5349)
# ['attack', 'bugbounty', 'burpsuite', 'burpsuite-engagement', 'burpsuite-intruder', 'fuzz', 'fuzz-lists', 'fuzzing', 'injection', 'intruder', 'payloads', 'sql-injection'] -> cybersecurity (Similarity: 0.4391)
# ['0day', 'exploit', 'poc', 'wordpress', 'wordpress-xmlrpc', 'xml-rpc'] -> system (Similarity: 0.3969)
# ['alibaba-nacos', 'jar', 'poc'] -> system (Similarity: 0.3625)
# ['poc', 'scanner', 'security-tools'] -> cybersecurity (Similarity: 0.5361)
# ['1panel', 'dashboard', 'docker', 'k8s', 'kubernetes', 'panel'] -> system (Similarity: 0.4931)
# ['command-line-tool', 'go', 'golang', 'gotty', 'kubectl', 'kubectl-plugins', 'kubeoperator', 'kubernetes'] -> system (Similarity: 0.3132)
# ['1password', '1password-connect', 'connect-sdk', 'go', 'golang', 'secrets-management'] -> cybersecurity (Similarity: 0.3439)
# ['1password', '1password-connect', 'golang', 'k8s', 'kubernetes', 'kubernetes-operator', 'secret-management'] -> cybersecurity (Similarity: 0.4072)
# ['golang-package', 'password-generator'] -> cybersecurity (Similarity: 0.2285)
# ['cli', 'ffi', 'rust', 'serde'] -> system (Similarity: 0.3918)
# ['go', 'golang', 'metrics', 'monitoring', 'queueing', 'rate-limit', 'throttle'] -> system (Similarity: 0.4277)
# ['align', 'false-sharing', 'go', 'go-vscode', 'golang', 'padding', 'structs', 'tool'] -> system (Similarity: 0.4339)
# ['clock', 'kindle', 'photo-album', 'tool', 'tools', 'weather', 'weibo'] -> system (Similarity: 0.4665)
# ['rdp', 'remote-control', 'remote-desktop', 'sftp', 'ssh', 'vnc', 'windows', 'windows-app', 'wpf-application'] -> cloud-computing (Similarity: 0.4097)
# ['iot', 'jdk8', 'mqtt', 'netty', 'spring-boot', 'yml'] -> system (Similarity: 0.5094)
# ['aws-cloudformation', 'aws-fargate'] -> cloud-computing (Similarity: 0.4722)
# ['bot', 'dns', 'http', 'privacy', 'privacy-online', 'raspberrypi', 'traffic-generator', 'traffic-inspection'] -> cybersecurity (Similarity: 0.4880)
# ['arduino', 'arduino-uno', 'ble', 'ble-beacons', 'bridge', 'esp32', 'esp8266', 'gateway', 'home-assistant', 'home-automation', 'lora', 'miflora', 'mqtt', 'nodemcu', 'openhab2', 'platformio', 'rcswitch', 'wemos-d1', 'xiaomi'] -> system (Similarity: 0.5062)
# ['android', 'burp-extensions', 'mobile-security', 'pentesting'] -> cybersecurity (Similarity: 0.3794)
# ['network-topology', 'pcap', 'python', 'security-tools'] -> cybersecurity (Similarity: 0.5370)
# ['aws-s3', 'dropbox', 'filesystem', 'flysystem', 'gaufrette', 'gridfs', 'php', 'rackspace', 'replicate', 'symfony'] -> system (Similarity: 0.5559)
# ['chunked-uploads', 'dropzone', 'fineuploader', 'gaufrette', 'php', 'plupload', 'symfony'] -> system (Similarity: 0.3575)
# ['alipay', 'antd', 'bitcoin', 'chatgpt', 'chinese', 'echarts', 'electron', 'funds', 'homebrew', 'linux', 'macos', 'menubar', 'react', 'redux', 'snapcraft', 'stock', 'typescript', 'wechat'] -> blockchain (Similarity: 0.5353)
# ['esp-cam', 'esp-idf', 'esp32', 'esp32-cam', 'm5camera', 'ov2640'] -> computer-vision (Similarity: 0.3657)
# ['emacs', 'org-mode', 'productivity', 'progressive-web-app', 'project-management'] -> web-development (Similarity: 0.5205)
# ['microsoft-services', 'spring-boot', 'spring-cloud', 'spring-cloud-alibaba', 'study-project'] -> cloud-computing (Similarity: 0.5300)
# ['book', 'crawl', 'novel', 'read', 'spider'] -> education (Similarity: 0.4456)
# ['book', 'cms', 'mybatis', 'novel', 'read', 'springboot'] -> system (Similarity: 0.4786)
#   0%|          | 740/185876 [00:01<06:34, 469.80it/s]
# ['github', 'github-api', 'github-extension'] -> web-development (Similarity: 0.2611)
# ['blog-engine', 'haskell', 'jekyll', 'latex', 'static-site-generator'] -> web-development (Similarity: 0.4350)
# ['vm', 'vmware', 'vmwareworkstation', 'workstation', 'workstation16'] -> system (Similarity: 0.3503)
# ['cop', 'cops', 'copwatch', 'justice', 'police', 'police-brutality', 'police-reports'] -> cybersecurity (Similarity: 0.4294)
# ['chrome-extension', 'hacktoberfest'] -> web-development (Similarity: 0.2490)
# ['binary', 'binary-exploitation', 'c', 'cpp', 'ghidra', 'ghidra-decompiler', 'ghidra-extension', 'python', 'reverse-engineering', 'vulnerability'] -> cybersecurity (Similarity: 0.4846)
# ['css', 'html', 'java', 'java8', 'javascript', 'mongodb', 'mysql', 'nodejs', 'vue'] -> web-development (Similarity: 0.5338)
# ['alpinejs', 'postcss', 'snowpack', 'tailwindcss'] -> system (Similarity: 0.3973)
# ['android', 'animation', 'compose-animation', 'jetpack-compose', 'kotlin'] -> computer-vision (Similarity: 0.3162)
# ['shell-script', 'v2ray', 'vmess'] -> system (Similarity: 0.3688)
# ['collaborate', 'fastapi', 'github', 'github-pages', 'hls', 'hls-live-streaming', 'iptv', 'live-streaming', 'm3u8', 'proxy', 'python', 'video-buffer'] -> cloud-computing (Similarity: 0.4187)
# ['python', 'schema', 'yaml'] -> system (Similarity: 0.4761)
# ['uni-app', 'uniapp'] -> education (Similarity: 0.3318)
# ['suspension-window', 'xuan-fu-chuang'] -> system (Similarity: 0.2803)
# ['community', 'holidays', 'open-source', 'opensource', 'pull-requests', 'rails', 'ruby'] -> system (Similarity: 0.4405)
# ['laravel', 'onelogin', 'saml-service-provider', 'saml2', 'sso'] -> system (Similarity: 0.3848)
# ['wechat'] -> system (Similarity: 0.3266)
# ['free', 'list', 'paas', 'saas'] -> system (Similarity: 0.4445)
# ['arduino', 'iot', 'mqtt'] -> system (Similarity: 0.4297)
# ['bson', 'database', 'go', 'golang', 'mongo', 'mongodb'] -> blockchain (Similarity: 0.4492)
# ['launcher', 'launchy', 'maya', 'maye', 'portable', 'productivity', 'quick-start', 'quickstart', 'run', 'startup', 'tool', 'windows'] -> system (Similarity: 0.4946)
# ['antd', 'antdesign', 'cude-ui', 'dva', 'dvajs', 'hooks', 'mobx', 'mobx-react', 'react', 'react-', 'react-redux', 'react-router', 'typescript', 'umi', 'umijs', 'vue', 'vue-cli-3', 'vuerouter', 'vuex'] -> system (Similarity: 0.3613)
# ['cross-platform', 'game', 'techmino', 'tetra'] -> system (Similarity: 0.4378)
# ['bibtex-references', 'commonsense', 'deep-learning', 'language-model', 'machine-learning', 'natural-language-processing', 'paper', 'reinforcement-learning', 'robotics', 'source-code-link', 'vision-and-language'] -> artificial-intelligence (Similarity: 0.7404)
# ['backscatter', 'color-balance', 'dark-channel-prior', 'denoise', 'dt-cwt', 'gaussian-pyramid', 'guidedfilter', 'haze-removal', 'image-enhancement', 'image-processing', 'java-8', 'laplacian-pyramid', 'matlab', 'opencv-java', 'retinex', 'underwater-image', 'video-processing', 'wavelet-transform'] -> computer-vision (Similarity: 0.6662)
# ['deeplearning4j', 'java', 'lstm', 'recurrent-neural-networks', 'spark-dataframes', 'stock-price-prediction'] -> data-science (Similarity: 0.4953)
# ['chatgpt', 'gpt-4', 'java', 'openai', 'rabittmq', 'springboot'] -> system (Similarity: 0.4194)
# ['openwrt'] -> blockchain (Similarity: 0.2223)
# ['ios-11', 'ios-iphone', 'iphone-x'] -> computer-vision (Similarity: 0.2539)
# ['csredis', 'redis', 'redis-client', 'redis-cluster', 'redis-sentinels'] -> cloud-computing (Similarity: 0.3428)
# ['client-side-caching', 'redis-client', 'redis-cluster-client', 'redis-pooling', 'redis-sentinel-client', 'redis6-client', 'resp3-client'] -> cloud-computing (Similarity: 0.2763)
# ['bootstrap4', 'druid', 'jpa', 'layui', 'springboot', 'thymeleaf'] -> system (Similarity: 0.3554)
# ['clojure', 'clojurescript'] -> cybersecurity (Similarity: 0.2666)
# ['2amigos', 'blade', 'blade-components', 'laravel', 'laravel-package', 'php', 'qr', 'qrcode', 'yii2'] -> system (Similarity: 0.3755)
# ['2amigos', 'chartjs', 'chartjs-widget', 'charts', 'php', 'yii'] -> data-science (Similarity: 0.3513)
# ['2amigos', 'blueimp', 'file-upload', 'jquery', 'php', 'upload-widget', 'yii'] -> system (Similarity: 0.3962)
# ['2amigos', 'google', 'maps', 'yii'] -> education (Similarity: 0.4491)
# ['android-app', 'java', 'storage'] -> system (Similarity: 0.4238)
# ['2captcha', 'anti-captcha', 'anticaptcha', 'bypass-invisible-recaptcha', 'bypass-recaptcha-v2', 'bypass-recaptcha-v3', 'bypasscaptcha', 'captcha-breaking', 'captcha-bypass', 'captcha-recognition', 'captcha-services-for-recaptcha-v2', 'captcha-solver', 'captcha-solving', 'deathbycaptcha', 'google-recaptcha-solver', 'recaptcha-solver', 'recaptcha-solver-python', 'recaptcha-v2-captcha-solver'] -> cybersecurity (Similarity: 0.2822)
# ['css', 'postcss', 'postcss-plugin', 'sprites', 'spritesheets', 'spritesmith', 'svg', 'svg-sprites'] -> computer-vision (Similarity: 0.4447)
# ['animation', 'framework', 'ios', 'macos', 'motion-design', 'swift'] -> computer-vision (Similarity: 0.4839)
# ['android'] -> system (Similarity: 0.2761)
# ['proxy', 'shadowsocks', 'socks5', 'trojan', 'v2fly', 'v2ray', 'vless', 'vmess', 'windows', 'xray', 'xtls'] -> system (Similarity: 0.4825)
# ['android', 'proxy', 'shadowsocks', 'socks5', 'trojan', 'v2fly', 'v2ray', 'vless', 'vmess', 'vpn', 'xray', 'xtls'] -> system (Similarity: 0.4550)
# ['hacktoberfest', 'kaamelott', 'onenagros', 'poulette', 'sloubi', 'soundboard'] -> system (Similarity: 0.3781)
#   0%|          | 812/185876 [00:01<05:45, 535.86it/s]
# ['authentication', 'ruby', 'security', 'two-factor', 'twofactorauth'] -> cybersecurity (Similarity: 0.4960)
# ['android-app', 'authentication', 'authenticator', 'c-sharp', 'ios-app', 'linux-app', 'password', 'totp', 'uwp-apps', 'windows-10'] -> system (Similarity: 0.3633)
# ['documentation', 'documentation-generator', 'documentation-tool', 'graphql'] -> web-development (Similarity: 0.3451)
# ['audio', 'html5', 'javascript', 'lu-yin', 'mp3', 'pcm', 'recorder', 'typescript', 'wav', 'web', 'webaudio'] -> web-development (Similarity: 0.4738)
# ['javascript', 'leaflet', 'map', 'webmaps'] -> web-development (Similarity: 0.4585)
# ['automation', 'webdriver', 'windows', 'winium'] -> system (Similarity: 0.3991)
# ['tvbox'] -> system (Similarity: 0.3162)
# ['devicons', 'github', 'portfolio', 'projects-list', 'showcase', 'vanilla-js', 'website'] -> web-development (Similarity: 0.4500)
# ['chroot', 'container', 'cross-architecture'] -> system (Similarity: 0.4511)
# ...
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File ~\anaconda3\envs\ecs260\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~\anaconda3\envs\ecs260\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\anaconda3\envs\ecs260\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\anaconda3\envs\ecs260\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# File ~\anaconda3\envs\ecs260\Lib\site-packages\tqdm\std.py:912, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     906 def wrapper(*args, **kwargs):
#     907     # update tbar correctly
#     908     # it seems `pandas apply` calls `func` twice
#     909     # on the first column/row to decide whether it can
#     910     # take a fast or slow code path; so stop when t.total==t.n
#     911     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 912     return func(*args, **kwargs)
#
# Cell In[18], line 19, in match_topic(repo_topics)
#      16     return "Unknown"
#      18 # 计算所有 `repo_topics` 的 embedding 并取平均值
# ---> 19 repo_embeddings = model.encode(repo_topics, convert_to_tensor=True)
#      20 avg_repo_embedding = torch.mean(repo_embeddings, dim=0, keepdim=True)  # 计算平均 embedding
#      22 # 计算 repo embedding 与 predefined topics 之间的相似度
#
# File ~\anaconda3\envs\ecs260\Lib\site-packages\sentence_transformers\SentenceTransformer.py:623, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, **kwargs)
#     620 features.update(extra_features)
#     622 with torch.no_grad():
# --> 623     out_features = self.forward(features, **kwargs)
#     624     if self.device.type == "hpu":
#     625         out_features = copy.deepcopy(out_features)
#
# File ~\anaconda3\envs\ecs260\Lib\site-packages\sentence_transformers\SentenceTransformer.py:690, in SentenceTransformer.forward(self, input, **kwargs)
#     688     module_kwarg_keys = self.module_kwargs.get(module_name, [])
#     689     module_kwargs = {key: value for key, value in kwargs.items() if key in module_kwarg_keys}
# --> 690     input = module(input, **module_kwargs)
#     691 return input
#
# File ~\anaconda3\envs\ecs260\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\ecs260\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\anaconda3\envs\ecs260\Lib\site-packages\sentence_transformers\models\Transformer.py:442, in Transformer.forward(self, features, **kwargs)
#     435 """Returns token_embeddings, cls_token"""
#     436 trans_features = {
#     437     key: value
#     438     for key, value in features.items()
#     439     if key in ["input_ids", "attention_mask", "token_type_ids", "inputs_embeds"]
#     440 }
# --> 442 output_states = self.auto_model(**trans_features, **kwargs, return_dict=False)
#     443 output_tokens = output_states[0]
#     445 # If the AutoModel is wrapped with a PeftModelForFeatureExtraction, then it may have added virtual tokens
#     446 # We need to extend the attention mask to include these virtual tokens, or the pooling will fail
#
# File ~\anaconda3\envs\ecs260\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\ecs260\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\anaconda3\envs\ecs260\Lib\site-packages\transformers\models\bert\modeling_bert.py:1142, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1135 # Prepare head mask if needed
#    1136 # 1.0 in head_mask indicate we keep the head
#    1137 # attention_probs has shape bsz x n_heads x N x N
#    1138 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#    1139 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#    1140 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# -> 1142 encoder_outputs = self.encoder(
#    1143     embedding_output,
#    1144     attention_mask=extended_attention_mask,
#    1145     head_mask=head_mask,
#    1146     encoder_hidden_states=encoder_hidden_states,
#    1147     encoder_attention_mask=encoder_extended_attention_mask,
#    1148     past_key_values=past_key_values,
#    1149     use_cache=use_cache,
#    1150     output_attentions=output_attentions,
#    1151     output_hidden_states=output_hidden_states,
#    1152     return_dict=return_dict,
#    1153 )
#    1154 sequence_output = encoder_outputs[0]
#    1155 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~\anaconda3\envs\ecs260\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\ecs260\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\anaconda3\envs\ecs260\Lib\site-packages\transformers\models\bert\modeling_bert.py:695, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     684     layer_outputs = self._gradient_checkpointing_func(
#     685         layer_module.__call__,
#     686         hidden_states,
#    (...)
#     692         output_attentions,
#     693     )
#     694 else:
# --> 695     layer_outputs = layer_module(
#     696         hidden_states,
#     697         attention_mask,
#     698         layer_head_mask,
#     699         encoder_hidden_states,
#     700         encoder_attention_mask,
#     701         past_key_value,
#     702         output_attentions,
#     703     )
#     705 hidden_states = layer_outputs[0]
#     706 if use_cache:
#
# File ~\anaconda3\envs\ecs260\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\ecs260\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\anaconda3\envs\ecs260\Lib\site-packages\transformers\models\bert\modeling_bert.py:585, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     573 def forward(
#     574     self,
#     575     hidden_states: torch.Tensor,
#    (...)
#     582 ) -> Tuple[torch.Tensor]:
#     583     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     584     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 585     self_attention_outputs = self.attention(
#     586         hidden_states,
#     587         attention_mask,
#     588         head_mask,
#     589         output_attentions=output_attentions,
#     590         past_key_value=self_attn_past_key_value,
#     591     )
#     592     attention_output = self_attention_outputs[0]
#     594     # if decoder, the last output is tuple of self-attn cache
#
# File ~\anaconda3\envs\ecs260\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\ecs260\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\anaconda3\envs\ecs260\Lib\site-packages\transformers\models\bert\modeling_bert.py:524, in BertAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     505 def forward(
#     506     self,
#     507     hidden_states: torch.Tensor,
#    (...)
#     513     output_attentions: Optional[bool] = False,
#     514 ) -> Tuple[torch.Tensor]:
#     515     self_outputs = self.self(
#     516         hidden_states,
#     517         attention_mask,
#    (...)
#     522         output_attentions,
#     523     )
# --> 524     attention_output = self.output(self_outputs[0], hidden_states)
#     525     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#     526     return outputs
#
# File ~\anaconda3\envs\ecs260\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\ecs260\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\anaconda3\envs\ecs260\Lib\site-packages\transformers\models\bert\modeling_bert.py:466, in BertSelfOutput.forward(self, hidden_states, input_tensor)
#     465 def forward(self, hidden_states: torch.Tensor, input_tensor: torch.Tensor) -> torch.Tensor:
# --> 466     hidden_states = self.dense(hidden_states)
#     467     hidden_states = self.dropout(hidden_states)
#     468     hidden_states = self.LayerNorm(hidden_states + input_tensor)
#
# File ~\anaconda3\envs\ecs260\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\ecs260\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\anaconda3\envs\ecs260\Lib\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
