# %%
from tqdm import tqdm
import pandas as pd
from sentence_transformers import SentenceTransformer, util
from langdetect import detect
from deep_translator import GoogleTranslator
import torch
import ast

# %%
df = pd.read_csv('C:/Users/29400/Desktop/data/original_data.csv')
df["topics"] = df["topics"].apply(ast.literal_eval)
model = SentenceTransformer("all-MiniLM-L6-v2")

# %%
tqdm.pandas()
predefined_topics = [
    "artificial-intelligence",
    "computer-vision",
    "web-development",
    "cybersecurity",
    "cloud-computing",
    "blockchain",
    "data-science",
    "education",
    "system"
]
predefined_embeddings = model.encode(predefined_topics, convert_to_tensor=True)
def match_topic(repo_topics):
    if not repo_topics:  # 如果 topic 为空，返回 "Unknown"
        return "Unknown"

    # 计算所有 `repo_topics` 的 embedding 并取平均值
    repo_embeddings = model.encode(repo_topics, convert_to_tensor=True)
    avg_repo_embedding = torch.mean(repo_embeddings, dim=0, keepdim=True)  # 计算平均 embedding

    # 计算 repo embedding 与 predefined topics 之间的相似度
    similarities = util.pytorch_cos_sim(avg_repo_embedding, predefined_embeddings)

    # 选择相似度最高的 predefined topic
    best_match_idx = torch.argmax(similarities)
    best_match = predefined_topics[best_match_idx]

    # print(f"{repo_topics} -> {best_match} (Similarity: {similarities[0][best_match_idx]:.4f})")
    return best_match

df["classified_topic"] = df["topics"].progress_apply(match_topic)
# Out:
# 100%|██████████| 185876/185876 [07:06<00:00, 435.32it/s]

# %%
# 替换模型为多语言 BERT
model = SentenceTransformer("paraphrase-multilingual-MiniLM-L12-v2")
def match_topic_with_readme(row):
    repo_topics = row["topics"]
    repo_readme = row["readme"]

    # 处理空值，确保 readme 不是 NaN
    if pd.isna(repo_readme):
        repo_readme = ""

    if not repo_topics and not repo_readme:
        return "Unknown"

    embeddings = []

    # 计算 repo_topics embedding
    if repo_topics:
        topic_embeddings = model.encode(repo_topics, convert_to_tensor=True)
        avg_topic_embedding = torch.mean(topic_embeddings, dim=0, keepdim=True)
        embeddings.append(avg_topic_embedding)

    # 计算 readme embedding（确保是字符串）
    if isinstance(repo_readme, str) and repo_readme.strip():
        readme_embedding = model.encode(repo_readme, convert_to_tensor=True).unsqueeze(0)
        embeddings.append(readme_embedding)

    # 计算整体 embedding（如果 topics 和 readme 都有，则取平均）
    if embeddings:
        avg_embedding = torch.mean(torch.cat(embeddings), dim=0, keepdim=True)
    else:
        return "Unknown"

    # 计算与 predefined_topics 的相似度
    similarities = util.pytorch_cos_sim(avg_embedding, predefined_embeddings)

    # 选择相似度最高的 topic
    best_match_idx = torch.argmax(similarities)
    best_match = predefined_topics[best_match_idx]

    return best_match

df["classified_topic_readme"] = df.progress_apply(match_topic_with_readme, axis=1)
# Out:
# 100%|██████████| 185876/185876 [44:14<00:00, 70.01it/s]

# %%
category = {"artificial-intelligence": 0, "computer-vision": 0, "web-development": 0, "cybersecurity": 0, "system": 0, "cloud-computing": 0, "blockchain": 0, "data-science": 0, "education": 0, "Unknown": 0}
for _, row in df.iterrows():
    classified_topic = row["classified_topic"]
    category[classified_topic] += 1
print(category)
# Out:
# {'artificial-intelligence': 13712, 'computer-vision': 10345, 'web-development': 8621, 'cybersecurity': 6872, 'system': 30351, 'cloud-computing': 5135, 'blockchain': 5479, 'data-science': 6964, 'education': 2690, 'Unknown': 95707}

# %%
category = {"artificial-intelligence": 0, "computer-vision": 0, "web-development": 0, "cybersecurity": 0, "system": 0, "cloud-computing": 0, "blockchain": 0, "data-science": 0, "education": 0, "Unknown": 0}
for _, row in df.iterrows():
    classified_topic = row["classified_topic_readme"]
    category[classified_topic] += 1
print(category)
# Out:
# {'artificial-intelligence': 42229, 'computer-vision': 21268, 'web-development': 48254, 'cybersecurity': 16122, 'system': 19400, 'cloud-computing': 4823, 'blockchain': 8112, 'data-science': 8990, 'education': 14698, 'Unknown': 1980}

# %%
df.to_csv("C:/Users/29400/Desktop/data/classified_data.csv", index=False)

# %%
df = pd.read_csv("C:/Users/29400/Desktop/data/classified_data.csv")

# %%
for _, row in df.iterrows():
    if row['classified_topic'] == "artificial-intelligence":
        print(row["topics"])
# Out:
# ['captcha-solving', 'gan', 'generative-adversarial-network', 'keras', 'neural-network', 'simgan']
# ['python', 'reverse-engineering']
# ['discord', 'discord-rpc', 'rich-presence', 'wine']
# ['random', 'thrift-store']
# ['api-hooking', 'cpp', 'pentesting-windows', 'redteaming']
# ['cnn', 'deep-learning', 'handwriting-recognition', 'machine-learning', 'rnn', 'tensorflow']
# ['bot', 'bot-api', 'bot-framework', 'nest', 'nestjs', 'nodejs', 'telegraf', 'telegram', 'telegram-bot', 'telegram-bot-api', 'typescript']
# ['android', 'frida', 'ios', 'mobile', 'reverse-engineering']
# ['active-directory', 'brute-force', 'information-gathering', 'metasploit-framework', 'penetration-testing']
# ['amm', 'awesome-list']
# ['awesome-list', 'derivatives']
# ['enumeration', 'persistence', 'privelage-escalation']
# ['artificial-neural-networks', 'blas', 'c', 'c99', 'cblas', 'classification', 'continuous-integration', 'efficient', 'embedded', 'feedforward-neural-network', 'header-only', 'machine-learning', 'matrix', 'neural-network', 'portable', 'regression', 'travis-ci', 'vectorization']
# ['algorithm', 'artificial-intelligence', 'continuous-optimization', 'discrete-optimization', 'evolutionary-algorithm', 'genetic-algorithm', 'genetic-algorithm-framework', 'harmony-search', 'hill-climbing', 'library', 'machine-learning', 'machine-learning-algorithms', 'metaheuristics', 'optimization', 'optimization-algorithms', 'particle-swarm-optimization', 'python', 'simulated-annealing', 'stochastic-optimizers', 'tabu-search']
# ['agents', 'ai', 'autogpt', 'gpt-4']
# ['prometheus-chinese', 'prometheus-cn', 'user-manual']
# ['ai', 'artificial-intelligence', 'azure', 'classification', 'computer-vision', 'content-tagging', 'hacktoberfest', 'ibm-watson', 'language-processing', 'machine-learning', 'microsoft-azure', 'ml', 'wordpress', 'wordpress-plugin']
# ['adb', 'cmd', 'python3', 'twilio-sms-api']
# ['irt', 'psychometrics', 'python']
# ['h5', 'mpvue', 'uniapp', 'vue', 'wepy']
# ['subtitle', 'tampermonkey', 'youtube', 'youtube-subtitle-downloader']
# ['apache-arrow', 'apache-mesos', 'apache-spark', 'artificial-intelligence', 'awesome-list', 'deep-learning', 'deep-learning-framework', 'federated-learning', 'knowledge-distillation', 'kubernetes', 'machine-learning', 'machine-learning-systems', 'model-compression', 'pruning', 'quantization']
# ['beta-vae', 'celeba', 'chairs-dataset', 'disentangled-representations', 'dsprites', 'unsupervised-learning', 'vae']
# ['beta-vae', 'celeba', 'chairs-dataset', 'disentangled-representations', 'dsprites', 'factor-vae', 'factorvae', 'unsupervised-learning', 'vae']
# ['adversarial-attacks', 'adversarial-example', 'machine-learning-security']
# ['classification', 'deep-learning', 'information-bottleneck', 'machine-learning', 'pytorch', 'variational-inference']
# ['bibtex-references', 'commonsense', 'deep-learning', 'language-model', 'machine-learning', 'natural-language-processing', 'paper', 'reinforcement-learning', 'robotics', 'source-code-link', 'vision-and-language']
# ['artificial-intelligence', 'future', 'knowledgedatabase', 'research', 'security']
# ['artificial-intelligence', 'learning', 'machine-learning', 'machine-learning-practice']
# ['learning', 'machine-learning', 'numpy', 'pandas', 'python-language', 'python-programming']
# ['api-wrapper', 'free-monads', 'github-wrapper', 'scala', 'scala-js']
# ['breathecode', 'exercise', 'exercises', 'gitpod', 'practice', 'python', 'python-autograded', 'python-beginners', 'python-exercises', 'python-interactive', 'python-interactive-exercises', 'python-interactive-tutorial', 'python-programming-exercises', 'python-tutorial', 'python-tutorials', 'tutorial', 'tutorial-code', 'tutorial-exercises', 'tutoriales', 'tutorials']
# ['nextjs', 'plausible', 'plausible-analytics']
# ['dataset', 'fifa', 'fifa18', 'video-game']
# ['kaggle', 'machine-learning', 'python']
# ['cocoapods', 'countries', 'countrypicker', 'flags', 'ios', 'phonecode', 'phonepicker', 'picker', 'swift', 'swift4', 'swift5', 'uipickerview']
# ['adacos', 'deep-learning', 'pytorch']
# ['pentest', 'python', 'remote-control']
# ['confuse', 'confusion', 'ios', 'mix', 'obfuscate', 'obfuscation', 'obfuscator', 'swift', 'tools']
# ['java', 'jvm', 'python']
# ['adam', 'elasticsearch', 'gensim', 'natural-language-processing', 'pandas', 'python', 'question-answering', 'scikit-learn', 'spacy', 'spacy-extension', 'wikipedia']
# ['aop', 'aspects', 'hook', 'hooks', 'ios', 'kvo', 'libffi', 'objective-c', 'runtime', 'swift', 'swizzle', 'swizzling']
# ['cmake', 'ray-tracer']
# ['batch-normalization-fuse', 'bnn', 'convolutional-networks', 'dorefa', 'group-convolution', 'integer-arithmetic-only', 'model-compression', 'network-in-network', 'network-slimming', 'neuromorphic-computing', 'onnx', 'post-training-quantization', 'pruning', 'pytorch', 'quantization', 'quantization-aware-training', 'tensorrt', 'tensorrt-int8-python', 'twn', 'xnor-net']
# ['algorithm', 'algorithms', 'go', 'golang', 'golang-leetcode', 'golang-solution', 'leetcode', 'leetcode-solutions']
# ['argv', 'command-line-parser', 'getopt', 'nodejs-modules', 'npm-package', 'option-parser']
# ['chat', 'chatbot', 'chatgpt', 'openai', 'react']
# ['evolutionary-algorithms', 'framework', 'metaheuristics', 'optimization', 'swarm-intelligence']
# ['vim-plugin']
# ['autotitle', 'bert', 'crf', 'gpt2', 'ner', 'pytorch', 'roberta', 'seq2seq', 't5-model', 'text-classification', 'unilm']
# ['gmm', 'neural-network', 'python', 'pytorch', 'zhihu']
# ['deeplearning', 'fastapi', 'framework', 'machine-learning', 'mlops', 'python']
# ['alpaca', 'chatgpt', 'deep-learning', 'fine-tuning', 'instruction-following', 'llm', 'lora', 'nlp', 'pytorch']
# ['amazon', 'amazon-captcha', 'amazon-scraper', 'amazoncaptcha', 'captcha', 'captcha-solver', 'data-extraction', 'pillow', 'python3', 'training-data']
# ['bagging', 'boosting-algorithms', 'bootstrap', 'islr', 'lda', 'linear-regression', 'logistic-regression', 'machine-learning', 'pca', 'random-forest', 'statistical-learning', 'supervised-learning']
# ['adventure', 'dungeon-crawler', 'game', 'ocaml', 'open-world', 'opengl', 'procedural', 'roguelike']
# ['bioinformatics', 'computational-biology', 'deep-learning', 'dgl', 'drug-discovery', 'gene-regulatory-networks', 'geometric-deep-learning', 'graph-neural-networks', 'interactome', 'interactomics', 'ppi-networks', 'protein', 'protein-data-bank', 'protein-design', 'protein-structure', 'python', 'pytorch', 'pytorch-geometric', 'rna', 'structural-biology']
# ['zero-knowledge']
# ['3d', 'blender-scripts', 'game-development', 'procedural-generation', 'python', 'spaceship']
# ['emw3031', 'mico', 'mqtt', 'phicomm', 'smart-contract', 'smart-home', 'tc1']
# ['anime', 'big5', 'game-development', 'gamedev', 'indie', 'indiedev', 'love2d', 'lua', 'programming', 'tutorial']
# ['box2d', 'game-development', 'love2d', 'lua', 'physics']
# ['cheat-sheets', 'cheatsheet', 'go', 'golang']
# ['blender-addon', 'blender-python', 'blender3d', 'procedural', 'procedural-generation']
# ['avo', 'geophysics', 'jupyter-notebook', 'petrophysics', 'python', 'rock-physics', 'tutorial']
# ['animated-text-kit', 'animation', 'dart', 'flutter', 'flutter-package', 'material-design', 'text-animation']
# ['dart', 'flutter', 'flutter-package', 'hacktoberfest', 'intro-screen', 'intro-views', 'material-design', 'material-ui', 'onboarding', 'page-reveal', 'welcome-page']
# ['aahnik', 'aahnik-daw', 'hacktoberfest', 'mtproto', 'python', 'python-script', 'python3', 'script', 'telegram', 'telegram-account', 'telegram-backup-bot', 'telegram-bot', 'telegram-chat', 'telegram-forward-bot', 'telegram-sync-bot', 'telegram-userbot', 'telethon', 'tgcf', 'user-bot']
# ['annotations', 'deep-learning', 'machine-learning', 'research', 'research-paper']
# ['awesome', 'awesome-list', 'books', 'compiler', 'interpreter', 'list', 'programming-language', 'resources', 'runtime', 'virtual-machine']
# ['approximate-bayesian-inference', 'gaussian-processes', 'jax', 'machine-learning', 'markov-gps', 'signal-processing', 'sparse-gps', 'state-space-models']
# ['confidence', 'deep-learning', 'evidence', 'neural-network', 'neurips-2020', 'pytorch', 'tensorflow', 'uncertainty']
# ['artificial-intelligence', 'classification', 'classifier', 'computer-vision', 'conformal', 'conformal-prediction', 'deep-neural-networks', 'distribution-free', 'imagenet', 'machine-learning', 'neural-networks', 'nonparametric', 'nonparametric-statistics', 'prediction-sets', 'pytorch', 'statistics', 'uncertainty', 'uncertainty-quantification', 'vision']
# ['3d-engine', 'reimplementation', 'renderware-graphics', 'reverse-engineering']
# ['anomaly-detection', 'artificial-intelligence', 'autoencoders', 'clustering', 'deep-learning', 'generative-adversarial-network', 'machine-learning', 'unsupervised-learning']
# ['aardvark', 'aardvark-platform', 'attribute-grammars', 'datastructures', 'fsharp', 'functional-programming', 'geometry', 'graphics', 'incremental-evaluation', 'linear-algebra', 'math', 'matrices', 'persistent-data-structure', 'tensors']
# ['recommendation-system', 'tensorflow']
# ['ascii-art', 'asciidots', 'esolang', 'esoteric-language', 'programming-language', 'python', 'python3']
# ['copy', 'cpd', 'detection', 'gradle-cpd-plugin', 'gradle-plugin', 'paste']
# ['compiler', 'interpreter', 'programing-language', 'virtual-machine']
# ['go', 'language', 'nlp', 'text-processing']
# ['bot', 'discord', 'discord-api', 'eris', 'nodejs']
# ['alipay', 'aop', 'mini-app', 'mini-program']
# ['python-library', 'streamdeck']
# ['bot', 'bots', 'slack', 'telegram']
# ['cnn', 'deeplearning', 'keras', 'lstm', 'machine-learning', 'python', 'sentiment-analysis', 'sentiment-classification']
# ['mapper', 'mybatis', 'mybatis-plugin']
# ['inference', 'nlp', 'nlp-machine-learning', 'onnx', 'onnxruntime', 'sentiment-analysis', 'summarization', 'text-classification', 'text-generation', 'transformer', 'transformers', 'translation']
# ['llvm', 'llvm-pass', 'tutorial']
# ['disassembler', 'elf', 'reverse-engineering']
# ['ai', 'chatgpt', 'cli', 'gpt3', 'gpt3-cli', 'openai']
# ['deep-learning', 'extract-features', 'open-set', 'openmax', 'softmax', 'softmax-regression']
# ['bert', 'classification', 'deep-learning', 'distilbert', 'named-entity-recognition', 'natural-language-processing', 'nlp', 'pytorch', 'pytorch-tutorial', 't5', 'transformers', 'wandb']
# ['anime', 'api', 'manga', 'myanimelist', 'python', 'rest', 'wrapper']
# ['deep-learning', 'deep-neural-networks', 'neural-networks', 'pytorch', 'tez']
# ['deep-learning', 'neural-style', 'pytorch']
# ['artificial-intelligence', 'computer-vision', 'deep-learning', 'deep-neural-networks', 'machine-learning']
# ['24projects', 'c-sharp', 'csharp', 'design-pattern', 'design-patterns', 'designpatterns', 'software-development']
# ['lilypond', 'music-composition', 'music-notation', 'python']
# ['genome-assembly', 'illumina', 'metagenome-assembly', 'next-generation-sequencing', 'sequence-assembler', 'sequencing', 'transcriptome-assembly']
# ['e-ink', 'e-paper', 'eink', 'epaper', 'python', 'raspberry-pi', 'raspberrypi', 'waveshare', 'weather']
# ['clojure', 'common-lisp', 'emacs-lisp', 'evaluation', 'navigation', 'python', 'refactoring', 'scheme']
# ['decorators', 'hacktoberfest', 'javascript', 'metadata', 'reflect-metadata', 'typescript']
# ['abstractive-summarization', 'abstractive-text-summarization', 'algorithms', 'amazon', 'data-science', 'deep-learning', 'machine-learning', 'natural-language-generation', 'natural-language-processing', 'opinion-summarization', 'reviews', 'summarization', 'vae', 'yelp']
# ['cli', 'subtitles', 'subtitles-generator', 'webui', 'whisper', 'whisper-ai']
# ['activerecord', 'django-like', 'eager-load', 'eager-loading', 'orm', 'orm-extension', 'sqlalchemy']
# ['book', 'machine-learning', 'machine-learning-algorithms', 'python']
# ['functional-components', 'functional-programming', 'functional-react', 'functional-reactive-programming']
# ['aho-corasick', 'algorithm', 'graph', 'keyword', 'lookup', 'pypi', 'python-library', 'unicode-support']
# ['autobot', 'onmyoji', 'python']
# ['animation', 'cut', 'editing', 'editorial', 'film', 'film-editing', 'interchange', 'interchange-format', 'nle', 'otio', 'timeline', 'vfx', 'video-editing']
# ['ci', 'ci-cd', 'continuous-delivery', 'continuous-integration', 'kubernetes']
# ['clojure', 'graphql', 'javascript', 'natural-language-generation', 'nlg', 'nocode', 'text-generation']
# ['awesome', 'awesome-list', 'natural-language-generation', 'natural-language-understanding', 'nlg']
# ['clojure', 'fuzzy-logic', 'natural-language-generation', 'number-to-text', 'number-to-words']
# ['adop']
# ['graph-embeddings', 'graph-representation-learning', 'knowledge-graph', 'knowledge-graph-embeddings', 'machine-learning', 'relational-learning', 'representation-learning']
# ['ida-plugin']
# ['book', 'chinese', 'computer-vision', 'deep-learning', 'jupyter-notebook', 'machine-learning', 'natural-language-processing', 'notebook', 'python']
# ['ace', 'ace-editor', 'diff', 'diffing', 'rich-text-editor']
# ['dice-coefficient', 'javascript', 'string-comparison', 'string-similarity', 'strings']
# ['leetcode', 'leetcode-solutions']
# ['e-ink', 'e-paper', 'epd', 'inkycal', 'python', 'raspberry-pi']
# ['ace-jump', 'easymotion', 'editor-plugin', 'emacs', 'ide', 'intellij', 'intellij-platform', 'intellij-plugin', 'keyboard', 'kotlin', 'search-interface', 'text', 'vim']
# ['bayesian-optimization', 'log-likelihood', 'matlab', 'noiseless-functions', 'noisy-functions', 'optimization-algorithms']
# ['bayesian-inference', 'data-analysis', 'gaussian-processes', 'machine-learning', 'matlab', 'variational-inference']
# ['classification', 'deep-learning', 'neural-networks', 'pytorch', 'semantic-segmentation']
# ['chatbot', 'google', 'google-bard', 'gpt', 'reverse-engineering']
# ['ai', 'anything', 'anythingv3', 'colab', 'f222', 'google-colab', 'image-generation', 'leaked', 'novelai', 'nsfw', 'r34', 'rule34', 'sd-v1-5', 'sd-v2-0', 'stable-diffusion', 'stable-diffusion-v1-5', 'waifu-diffusion']
# ['bing-ai', 'binggpt', 'chatgpt', 'edge', 'edgegpt', 'gpt', 'reverse-engineering']
# ['deep-learning', 'finance', 'machine-learning', 'prediction', 'python-library', 'quantitative-finance', 'quantitative-trading', 'sentiment-analysis', 'stock-market', 'stock-market-prediction', 'stock-prediction']
# ['asyncio', 'library', 'python', 'utils']
# ['ai', 'audio', 'deep-learning', 'generative-model', 'neural-network']
# ['icons', 'world-of-warcraft']
# ['automation', 'ci', 'drupal']
# ['circular', 'command-line', 'dependency', 'javascript', 'madge', 'typescript', 'typescript3', 'visualization']
# ['advantage', 'algorithm', 'fbp', 'football', 'football-lottery', 'football-simulation', 'footballpredictor', 'lottery-program', 'lottery-tickets', 'machine-learning-algorithms', 'prediction', 'prediction-model']
# ['engine', 'gamification', 'gamification-engine', 'gamification-framework', 'gamification-platform', 'python', 'rules-engine']
# ['actions', 'github', 'regex']
# ['gh-extension', 'golang']
# ['actions', 'actionsflow', 'automate', 'hacktoberfest', 'ifttt', 'workflow', 'zapier']
# ['cnn', 'convolutional-neural-networks', 'deep-learning', 'deep-neural-networks', 'lenet5', 'machine-learning', 'pytorch']
# ['agent', 'agents', 'ai', 'automation', 'automation-tools', 'business-automation', 'enterprise-automation', 'llm', 'low-code', 'n8n', 'no-code', 'powerautomate', 'self-hosted', 'tray', 'typescript', 'workato', 'workflow', 'workflow-automation', 'zapier']
# ['actix', 'actor', 'actor-model', 'concurrency', 'hacktoberfest', 'rust']
# ['actor-model', 'actors', 'async', 'caf', 'pattern-matching']
# ['deep-reinforcement-learning', 'drl', 'gazebo', 'gym', 'reinforcement-learning', 'rl', 'robotics', 'ros', 'ros2']
# ['despot', 'online', 'planning', 'pomdp', 'uncertainty']
# ['adafruit-io']
# ['batch-normalization', 'convolutional-networks', 'coursera', 'deep-learning', 'neural-network', 'optimization', 'regularization']
# ['c', 'compiler', 'compiler-design', 'golang']
# ['capsnet', 'capsules', 'deep-learning', 'dynamic-routing-between-capsules', 'machine-learning', 'mnist', 'pytorch']
# ['contrastive-loss', 'deep-learning', 'embedding', 'learning-embeddings', 'machine-learning', 'pytorch', 'siamese-network', 'triplet-loss', 'triplet-network']
# ['barcod', 'bwipp', 'python']
# ['martin-fowler-book', 'php', 'refactoring', 'refactoring-functions']
# ['ai', 'deep-learning', 'deep-neural-networks', 'machine-learning', 'model-reuse', 'neural-networks', 'neurips-2022', 'transfer-learning']
# ['mocha', 'mocha-reporter', 'reporter', 'tdd']
# ['quantum-computing', 'quantum-simulator']
# ['ai', 'amazon', 'artificialintelligence', 'brave', 'chat', 'chatbot', 'chatgpt', 'chrome-extensions', 'duckduckgo', 'firefox-addons', 'google', 'gpt-4', 'greasemonkey', 'javascript', 'machine-learning', 'ml', 'nlp', 'openai', 'userscripts', 'web-extensions']
# ['ai', 'captcha', 'chatgpt', 'cloudflare', 'discourse', 'duckduckgo', 'greasemonkey', 'javascript', 'mturk', 'openai', 'privacy', 'search', 'tampermonkey', 'userscripts', 'vbulletin', 'violentmonkey', 'xenforo', 'youtube']
# ['python', 'sms']
# ['cross-platform', 'intrinsics', 'optimization', 'simd']
# ['ios', 'swift', 'validation', 'validation-library', 'validators']
# ['ai', 'android', 'artificial-intelligence', 'cpp', 'deep-learning', 'federated-analytics', 'federated-learning', 'federated-learning-framework', 'fleet-intelligence', 'fleet-learning', 'flower', 'framework', 'grpc', 'ios', 'machine-learning', 'python', 'pytorch', 'raspberry-pi', 'scikit-learn', 'tensorflow']
# ['adapters', 'bert', 'lora', 'natural-language-processing', 'nlp', 'parameter-efficient-learning', 'parameter-efficient-tuning', 'pytorch', 'transformers']
# ['framework', 'jax', 'neuroevolution', 'quality-diversity', 'reinforcement-learning', 'research']
# ['finance', 'fx', 'interop', 'openfin', 'pwa', 'react', 'real-time', 'rxjs', 'storybook', 'typescript']
# ['contrastive-learning', 'machine-learning', 'neuroscience-methods', 'pytorch']
# ['computational-linguistics', 'corpus-linguistics', 'german-language', 'natural-language-processing', 'nlp', 'text-mining']
# ['article-extractor', 'corpus-builder', 'corpus-tools', 'crawler', 'html-to-markdown', 'html2text', 'llm', 'news-aggregator', 'news-crawler', 'nlp', 'rag', 'readability', 'rss-feed', 'scraping', 'tei', 'text-cleaning', 'text-extraction', 'text-mining', 'text-preprocessing', 'web-scraping']
# ['adblock', 'adblockradio', 'ai', 'keras', 'machine-learning', 'shazam', 'signal-processing', 'tensorflow']
# ['mobile-ui', 'vue', 'vue-components', 'vue-weui', 'wechat-mobile-ui', 'weui']
# ['auditing-predictive-models', 'discrimination', 'fairness', 'model-criticism', 'prediction-model', 'toolbox']
# ['deep-learning', 'information-retrieval', 'neural-network']
# ['android', 'automation', 'autoreply', 'chatbot', 'facebook', 'facebook-bot', 'messengers', 'privacy', 'privacy-tools', 'signal', 'telegram', 'whatsapp', 'whatsapp-bot']
# ['chatbot', 'facebook-messenger-bot', 'seq2seq-model', 'tensorflow']
# ['lstm', 'rnn', 'sentiment-analysis', 'tensorflow']
# ['machine-learning']
# ['deep-learning', 'machine-learning', 'tensorflow']
# ['android', 'android-library', 'event-tracking', 'geo-search', 'geolocation', 'geolocation-api', 'google', 'google-maps', 'hacktoberfest', 'kotlin', 'kotlin-library', 'library', 'location', 'location-picker', 'maps', 'multi-language', 'place-picker', 'placepicker', 'rtl', 'search-by-voice']
# ['3d-printing', 'bezier-path', 'control', 'gait', 'gait-generation', 'locomotion', 'machine-learning', 'quadruped', 'quadruped-robot', 'quadruped-robots', 'reinforcement-learning', 'robotics', 'trajectory', 'trajectory-generation']
# ['applescript', 'bash', 'python']
# ['cheat-sheets', 'convolutional-networks', 'data-science', 'deep-learning', 'deep-neural-networks', 'gans', 'harvard-edx', 'interview-questions', 'machine-learning', 'python']
# ['climate-change', 'climate-science', 'deep-learning', 'machine-learning']
# ['anime', 'artificial-intelligence', 'doki-doki-literature-club', 'eye-tracking', 'face-detection', 'haar-cascade', 'opencv', 'pygame', 'python3', 'waifu']
# ['artificial-intelligence', 'computer-vision', 'deep-learning', 'machine-learning', 'neural-network', 'yolo']
# ['compiler', 'deep-learning', 'docker-images', 'inference', 'inference-engine', 'model-optimizer', 'openvino', 'tensorflow-serving', 'tensorrt']
# ['xapi']
# ['xapi']
# ['aliyundrive']
# ['adobe-experience-manager', 'aem', 'code-samples', 'cq', 'java', 'jcr', 'oak', 'osgi', 'sling']
# ['adobe-experience-manager', 'aem', 'cq']
# ['cplusplus', 'documentation-tool', 'jekyll', 'libtooling']
# ['airpods', 'android-app', 'reverse-engineering']
# ['bok', 'bookfi', 'books', 'genlibrus', 'libgen', 'python']
# ['g2p', 'lexicon', 'openfst', 'pronunciation-dictionary', 'speech-recognition', 'speech-to-text']
# ['comics', 'hacktoberfest', 'manga', 'manga-reader', 'manga-web', 'reader']
# ['core', 'schema-validator', 'validation-engine']
# ['analytics', 'ember', 'ember-addon', 'ember-metrics']
# ['ember', 'ember-addon', 'ember-paper', 'material-design']
# ['erlang']
# ['architectural-decision-records', 'architectural-decisions', 'architecture-decision-records', 'architecture-doc', 'software-architecture-and-design']
# ['pomodoro', 'pomodoro-timer', 'productivity-timer', 'time-management']
# ['course', 'deep-learning', 'julia', 'machine-learning', 'tutorial']
# ['ai', 'chatbot', 'chatgpt', 'cli', 'conversational', 'conversational-ai', 'conversational-bots', 'customizable', 'elevenlabs', 'gpt-3', 'gpt-4', 'memory', 'openai', 'personalized', 'python', 'speech-recognition', 'speech-to-text', 'tts', 'user-friendly', 'voice-recognition']
# ['advertising', 'android-library', 'beacon', 'ble', 'bluetooth-low-energy', 'broadcast-bluetooth-beacons', 'eddystone-beacons', 'eddystone-eid', 'eddystone-gatt', 'eddystone-uid', 'eddystone-url', 'eid-beacon', 'gatt-service']
# ['code-golf', 'elixir', 'esolang', 'esoteric-language', 'golfing-language', 'hacktoberfest', 'interpreter', 'stack-based']
# ['data-science', 'deep-learning', 'deep-neural-networks', 'keras', 'machine-learning', 'python', 'scikit-learn', 'tensorflow', 'wrappers']
# ['react', 'react-project', 'reactjs', 'voice-assistant', 'voice-recognition']
# ['ai', 'chatgpt']
# ['jekyll', 'jekyll-site', 'jekyll-theme', 'minimalist']
# ['automatic', 'dotnet', 'malware', 'unpacking']
# ['adversarial-attacks', 'adversarial-example', 'adversarial-examples', 'deep-learning', 'deepfool', 'fgsm', 'graphpipe', 'machine-learning', 'onnx', 'paddlepaddle', 'security']
# ['crawler', 'jingdong', 'python', 'scraper']
# ['autocompletion', 'bash-completion', 'command-line', 'completions', 'productivity', 'zsh-completions']
# ['epub', 'python', 'python-library']
# ['aesara', 'automatic-differentiation', 'optimizing-compiler', 'optimizing-compilers', 'symbolic-computation', 'tensors', 'term-rewriting-system', 'theano', 'transpiler']
# ['javascript', 'lazy-evaluation', 'lazyload', 'lazysizes', 'performance', 'responsive-images']
# ['autocomplete', 'autocomplete-search', 'component', 'frontend', 'javascript', 'stimulus', 'stimulusjs']
# ['backbone', 'backbone-models', 'nested-attributes']
# ['bch', 'channel-coding', 'cpp', 'decoding', 'error-correcting-codes', 'fec', 'forward-error-correction', 'ldpc', 'ldpc-codes', 'library', 'mpi', 'multi-threading', 'multithreading', 'polar', 'polar-codes', 'reed-solomon', 'simulation', 'turbo', 'turbo-codes', 'turbo-product-codes']
# ['artificial-intelligence', 'music-generation']
# ['gpt2', 'language-model', 'natural-language-generation', 'natural-language-processing', 'nlp', 'pytorch', 'transformer']
# ['artificial-intelligence', 'deep-learning', 'diffusion', 'image-generation', 'multimodal', 'multimodality', 'openai', 'openai-clip', 'text-to-image', 'text-to-image-synthesis']
# ['afl', 'afl-fuzz', 'aflplusplus', 'binary-only', 'coverage-guided', 'frida', 'fuzzing', 'fuzzing-framework', 'libafl', 'rust']
# ['a-star', 'artificial-intelligence', 'bayesian-networks', 'cheatsheet', 'constraint-satisfaction-problem', 'data-science', 'markov-decision-processes']
# ['cheatsheet', 'cs229', 'data-science', 'deep-learning', 'machine-learning', 'ml-cheatsheet', 'supervised-learning', 'unsupervised-learning']
# ['neural-network', 'nn', 'rust']
# ['ipython-notebook', 'kaggle-competition', 'kaggle-titanic', 'machine-learning', 'python']
# ['deep-learning', 'deprecated', 'distributed', 'jupyter-notebook', 'machine-learning', 'ml', 'neural-network', 'python', 'scikit-learn', 'tensorflow']
# ['adapters', 'fine-tuning', 'large-language-models', 'parameter-efficient']
# ['decorators', 'dependency-injection', 'ioc', 'vue3']
# ['agilerl', 'automl', 'deep-learning', 'deep-reinforcement-learning', 'distributed', 'evolutionary-algorithms', 'gym', 'hpo', 'hyperparameter-optimization', 'hyperparameter-tuning', 'machine-learning', 'mlops', 'multi-agent', 'multi-agent-reinforcement-learning', 'pettingzoo', 'python', 'pytorch', 'reinforcement-learning', 'rlops', 'training']
# ['agi', 'llm', 'opensource']
# ['home-assistant-config', 'homeassistant', 'lovelace', 'lovelace-ui']
# ['deep-learning', 'generative-adversarial-network', 'human-trajectory-prediction', 'pytorch', 'social-navigation', 'trajectory-prediction']
# ['github-pages', 'jekyll', 'jekyll-theme']
# ['elixir', 'json', 'protobuf', 'protobuf-message', 'protobuf-runtime', 'protoc', 'protocol-buffers']
# ['deep-learning', 'machine-learning', 'tensorflow']
# ['python', 'python3', 'ulid', 'uuid']
# ['powershell', 'powershell-module', 'qliksense']
# ['aheui', 'self-interpreter']
# ['angularjs', 'c-plus-plus', 'caffe2', 'convert-pytorch-models', 'deep-learning', 'deep-neural-networks', 'flask', 'keras', 'model-serving', 'mxnet', 'production', 'python', 'pytorch', 'react', 'rest-api', 'serving', 'serving-pytorch-models', 'tensorflow-models', 'tesnorflow', 'tutorial']
# ['alfred-snippets', 'emoji', 'emoji-log', 'emoji-meaning', 'git', 'vscode', 'workflow']
# ['ai-engine', 'bots', 'chatbot', 'chatbotai', 'chatbots', 'python', 'python-chatbot']
# ['character-based-model', 'character-cnn', 'convolutional-neural-network', 'deep-neural-networks', 'natural-language-processing', 'nlp', 'nlp-machine-learning', 'paper-implementations', 'pytorch', 'youtube-video']
# ['backpropagation', 'batch-gradient-descent', 'decision-boundary', 'loss', 'neural-networks', 'numpy', 'python', 'tutorial']
# ['deep-learning', 'evolutionary-algorithms', 'genetic-algorithm', 'machine-learning', 'neural-networks', 'numpy', 'optimization', 'pygad', 'pygad-documentation', 'python']
# ['deep-learning', 'genetic-algorithm', 'neural-networks', 'optimization', 'pygad', 'python']
# ['art', 'circles', 'evolutionary-algorithms', 'evolutionary-art', 'genetic-algorithm']
# ['clean-architecture', 'clean-code', 'dart', 'ddd', 'domain-driven-design', 'fcm', 'firebase', 'flutter', 'go-router', 'google-maps', 'layered-architecture', 'local-notifications', 'riverpod', 'tdd', 'unit-testing']
# ['language', 'morphology', 'nlp', 'turkish', 'zemberek-nlp']
# ['academic-writing', 'ai-writing', 'chatgpt', 'chatgpt-prompts', 'customgpt', 'gpt3', 'gpt35', 'gpt4', 'literature-review', 'prompt', 'writing']
# ['asr', 'automatic-speech-recognition', 'docker', 'openai-whisper', 'speech', 'speech-recognition', 'speech-to-text']
# ['automation', 'gmail', 'script']
# ['animation', 'animation-library', 'animejs', 'beginner-friendly', 'comparison', 'popmotion', 'react', 'react-spring']
# ['awesome', 'awesome-list', 'datasets', 'deep-learning', 'image-segmentation', 'list', 'lists', 'machine-learning', 'optimization', 'optimization-algorithms', 'physics', 'planning-algorithms', 'point-cloud', 'reinforcement-learning', 'robot', 'robotics', 'ros', 'sensors', 'simulation', 'tensorflow']
# ['first-person', 'html5', 'javascript', 'raycast', 'raycasting', 'react']
# ['atis', 'attention', 'bert', 'bert-model', 'bilstm-crf', 'classification', 'conll-2003', 'elmo', 'factrueval', 'joint-models', 'ner', 'ner-task', 'nlp', 'nmt', 'python', 'python3', 'pytorch', 'pytorch-model', 'transfer-learning']
# ['dalle', 'image-generation', 'openai', 'python', 'pytorch', 'russian', 'russian-language', 'text-to-image', 'transformer']
# ['ai', 'browser-extension', 'chatgpt', 'chrome-extension']
# ['awesome-list', 'competition-code', 'deep-learning', 'kaggle', 'machine-learning']
# ['aigc', 'stable-diffusion-tutorial']
# ['bert', 'indian-languages', 'language-model', 'multilingual-models', 'nlp']
# ['awesome-list', 'corpora', 'indian-languages', 'libraries', 'models']
# ['a2c', 'bipedalwalkerhardcore', 'ddpg', 'dqn', 'drl-pytorch', 'efficient', 'gae', 'lightweight', 'model-free-rl', 'multiple-gpu', 'per', 'ppo', 'pytorch', 'reinforcement-learning', 'sac', 'stable', 'td3']
# ['chatgpt', 'finance', 'fingpt', 'fintech', 'large-language-models', 'machine-learning', 'nlp', 'prompt-engineering', 'pytorch', 'reinforcement-learning', 'robo-advisor', 'sentiment-analysis', 'technical-analysis']
# ['deep-reinforcement-learning', 'drl-trading-agents', 'finance', 'finrl-library', 'fintech', 'openai', 'openai-gym-environments']
# ['a2c-algorithm', 'automated-stock-trading', 'ddpg', 'deep-reinforcement-learning', 'ensemble-strategy', 'openai-gym', 'ppo', 'sharpe-ratio', 'stock-trading', 'stock-trading-strategy']
# ['algorithmic-trading', 'deep-reinforcement-learning', 'drl-algorithms', 'drl-framework', 'drl-trading-agents', 'finance', 'fintech', 'multi-agent-learning', 'openai-gym', 'pythorch', 'stock-markets', 'stock-trading', 'tensorflow2', 'trading-tasks']
# ['deep-learning', 'machine-learning', 'neural-network', 'python']
# ['ai', 'artificial-intelligence', 'bots', 'chatbot', 'chatbots', 'rivescript']
# ['best-practices', 'blockdom', 'compiler', 'hacktoberfest', 'memo', 'million', 'millionjs', 'optimization', 'optimize', 'performance', 'preact', 'react', 'react-hooks', 'react-optimize', 'renderer', 'rendering', 'virtual-dom']
# ['chatgpt', 'python']
# ['action-creator', 'flux', 'fsa', 'redux', 'typescript']
# ['dinov2', 'generalist-model', 'in-context-segmentation', 'matcher', 'sam']
# ['continual-learning', 'dark-experience-replay', 'deep-learning', 'der', 'experience-replay', 'knowledge-distillation', 'neurips2020', 'pytorch']
# ['automated-machine-learning', 'automation', 'automl', 'evolutionary-algorithms', 'fedot', 'genetic-programming', 'hyperparameter-optimization', 'machine-learning', 'multimodality', 'parameter-tuning', 'structural-learning']
# ['ai', 'computer-vision', 'cs231n', 'cv', 'deep-learning', 'dl', 'jianzhioffer', 'machine-learning', 'ml', 'nlp']
# ['chatgpt', 'chatgpt-api', 'cli', 'openai', 'python']
# ['aioredis', 'asyncio', 'hacktoberfest', 'python', 'python-3', 'python3', 'python310', 'python36', 'python37', 'python38', 'python39', 'redis', 'redis-client', 'redis-sentinel']
# ['aiohttp', 'api-client', 'asyncio', 'docker', 'python']
# ['aiohttp', 'async-await', 'asyncio']
# ['aiohttp', 'asyncio', 'cors']
# ['aiohttp', 'asyncio']
# ['aiohttp', 'asyncio', 'jinja2']
# ['aiohttp', 'asyncio']
# ['aiohttp', 'asyncio']
# ['aiohttp', 'asyncio', 'jobs']
# ['asyncio', 'memcached']
# ['async-await', 'asyncio', 'mypy', 'uvloop']
# ['aiohttp', 'async-await', 'asyncio', 'dapper', 'distributed-tracing', 'jaeger', 'mypy', 'stackdriver', 'zipkin']
# ['aiohttp', 'asyncio', 'sockjs', 'websockets']
# ['aiogram', 'asyncio', 'bot', 'bot-framework', 'python', 'telegram-bot', 'telegram-bot-api']
# ['deep-learning', 'force-field', 'molecular-simulation', 'neural-network', 'quantum-chemistry', 'quantum-mechanics']
# ['deep-learning', 'information-retrieval', 'keras', 'natural-language-processing', 'nlp']
# ['deep-learning', 'information-retrieval', 'learning-to-rank', 'ltr', 'machine-learning', 'neural-network']
# ['classification', 'deep-learning', 'keras', 'natural-language-processing', 'nlp']
# ['bert', 'distillation', 'knowledge', 'nlp', 'pytorch']
# ['model-pruning', 'pre-trained-language-models', 'pruning', 'transformer']
# ['android', 'annotation-processor', 'deep-links']
# ['airbrake', 'error-reporting', 'go', 'golang', 'notifier']
# ['decompiler', 'disassembler', 'ghidra', 'ida-plugin', 'reverse-engineering']
# ['es6', 'mini-program', 'wechat-app']
# ['ai', 'game', 'games', 'head', 'headtracker', 'opentrack', 'simulator', 'tracker', 'tracking']
# ['asyncio', 'clash', 'disney', 'netflix', 'pyrogram', 'python', 'speedtest', 'telegram', 'telegram-bot', 'youtube']
# ['airspeed-velocity', 'benchmark', 'python']
# ['android', 'automated-testing', 'automation', 'game', 'ios', 'test-automation', 'test-framework', 'unity3d', 'windows']
# ['automated-testing', 'automation', 'ios', 'ios-app', 'ios-ui']
# ['android', 'automated-testing', 'automation', 'game', 'test-automation', 'test-framework', 'unity3d']
# ['axios', 'js', 'rate-limit', 'rate-limiting', 'rate-limits', 'ratelimit', 'ratelimiter', 'ratelimiting', 'typescript']
# ['animations', 'javascript', 'jquery', 'jquery-animatenumber', 'jquery-plugin']
# ['gre']
# ['csv', 'flutter', 'flutter-apps', 'globalization', 'i18n', 'i18n-alternative', 'internationalization', 'json', 'json-files', 'json-localization', 'locale', 'locale-gen', 'locales', 'locales-translation', 'localization', 'localization-kit', 'localization-tool', 'localization-using-json-files', 'translated-keys', 'translation']
# ['anomaly-detection', 'deep-learning', 'deep-neural-networks', 'forecasting', 'hacktoberfest', 'lstm', 'pytorch', 'state-of-the-art-models', 'time-series', 'time-series-analysis', 'time-series-forecasting', 'time-series-regression', 'transfer-learning', 'transformer']
# ['dataset-generation', 'deep-learning', 'gtav', 'reinforcement-learning', 'self-driving-car']
# ['custom-props', 'default-props', 'javascript', 'react-native']
# ['argument-parser', 'argument-parsing', 'cli', 'command-line', 'command-line-parser', 'kotlin', 'kotlin-library', 'option-parser']
# ['ajatt', 'anki', 'anki-cards', 'flashcards', 'language-learning', 'lua', 'mpv', 'mpv-script', 'spaced-repetition', 'subs2srs', 'subtitles', 'yomichan']
# ['anamoly-detection-using-graphs', 'anomaly-detection', 'correlation', 'data-analysis', 'deep-learning', 'deep-neural-networks', 'explainable-artificial-intelligence', 'feature-engineering', 'feature-selection', 'multidimensional-data', 'multisensor', 'python', 'pytorch', 'sensor', 'sensor-data', 'signal-processing', 'tabular-data', 'time-series', 'variation', 'visualization']
# ['andrew-ng-machine-learning', 'andrew-ng-machine-learning-yearning', 'deep-learning', 'deep-learning-andrew-ng', 'deeplearning-ai', 'machine-learning', 'machine-learning-coursera', 'machine-learning-yearning']
# ['biggan', 'deep-learning', 'dogball', 'gans', 'neural-networks', 'pytorch']
# ['deep-learning', 'densenet', 'machine-learning', 'memes', 'neural-networks', 'pytorch', 'vgg16', 'wide-residual-networks']
# ['find', 'fuzzy', 'fuzzy-match', 'fuzzy-search', 'fzf', 'javascript', 'js', 'search']
# ['2015', '2016', '2017', 'memory-analysis', 'pdb', 'reclass', 'reclass2015', 'reclass2016', 'reclass2017', 'reclass64', 'reclassex', 'reclassx64', 'rtti', 'symbols', 'x64']
# ['discord', 'discord-bot', 'discord-js', 'nodejs', 'selfbot', 'spambot']
# ['cpp', 'flex-engine', 'game-engine', 'glsl', 'personal-game-engine', 'rendering-engine', 'vulkan']
# ['api', 'cloudflare', 'cloudflare-worker', 'kanye', 'kanye-west', 'quote', 'quote-generator', 'quotes', 'random', 'worker', 'workers']
# ['extract-pdf-text', 'markdown', 'obsidian', 'pdf']
# ['faker', 'faker-bot', 'faker-cli', 'faker-gem']
# ['c', 'lightweight', 'lw-oopc', 'object-oriented', 'oop']
# ['python', 'python3']
# ['adversarial-machine-learning', 'celeba', 'deep-learning', 'gan', 'machine-learning', 'msg-gan']
# ['gpt', 'gpt-2', 'gpt2', 'implementation', 'nlp', 'openai', 'pre-training', 'pretraining', 'tensorflow', 'tensorflow2', 'text-generation', 'transformer']
# ['biosignals', 'cnn', 'deep-learning', 'eeg', 'lstm', 'neural-network', 'scoring-sleep-stages', 'sleep', 'sleep-analysis']
# ['hotpotqa', 'multi-hop-reasoning', 'natural-questions', 'open-domain-qa', 'reading-comprehension', 'retrieval', 'squad']
# ['4x-strategy-game', 'english-language', 'free', 'french-language', 'game', 'german-language', 'hungarian-language', 'imperium-galactica', 'java', 'magyar', 'russian-language', 'space-game']
# ['extensions', 'reactive-streams', 'rxjava']
# ['extensions', 'interoperation', 'reactive-streams', 'rxjava']
# ['django', 'django-application', 'django-framework', 'django-project', 'open-source', 'opensource', 'python', 'python3', 'question-answering', 'quiz-app', 'quiz-game', 'quizapp', 'quizzes']
# ['components', 'library', 'neumorphic', 'neumorphism', 'neumorphism-ui', 'react', 'reactjs', 'reactjs-components', 'skeumorphism', 'ui', 'ui-neumorphism', 'web']
# ['app', 'cordova', 'movie', 'vue', 'vue-cli', 'vuex']
# ['android-apps', 'automatic-translation', 'microsoft-translator-api', 'xposed', 'yandex-translate']
# ['coreml', 'coremltools', 'deep-learning', 'deep-neural-networks', 'demo', 'ios', 'ios11', 'keras', 'machine-learning', 'rnn', 'swift']
# ['auto-complete', 'bash', 'bash-configuration', 'blesh', 'line-editor', 'syntax-highlighting', 'vim-mode']
# ['hep', 'hep-lat', 'hmc', 'hpc', 'julia', 'julia-language', 'julialang', 'lattice-field-theory', 'lattice-gauge-theory', 'lattice-qcd', 'monte-carlo', 'particle-physics', 'physics', 'qcd', 'sciml']
# ['carousel', 'react', 'slick']
# ['akka', 'akka-http', 'grpc', 'java', 'reactive', 'reactive-streams', 'rpc', 'scala', 'streaming']
# ['akka']
# ['akka', 'akka-streams', 'java', 'kafka', 'kafka-client', 'kafka-connector', 'reactive', 'reactive-streams', 'scala']
# ['akka', 'akka-stream', 'akka-streams-connectors', 'hacktoberfest', 'integration', 'messaging', 'reactive', 'reactive-streams']
# ['c-plus-plus', 'fexprs', 'lisp', 'lisp-1', 'lisp-interpreter', 'literate-programming', 'programming-language', 'unit-tested']
# ['plantuml', 'vim-syntax']
# ['cordova', 'cordova-plugin', 'swift']
# ['gensim', 'nlp', 'turkish', 'word2vec']
# ['code-golf', 'javascript-game', 'minimalism']
# ['interpreter', 'python']
# ['autopilot', 'dataset', 'deep-learning', 'driving-cars', 'machine-learning', 'nvidia', 'research-paper', 'self-driving-car', 'tesla']
# ['nlp', 'numeric-digits', 'python', 'word-to-number']
# ['beginner', 'beginner-friendly', 'learn-to-code', 'learning-python', 'oop', 'python', 'python-3', 'python-tutorial', 'tutorial', 'tutorials']
# ['distributional-semantics', 'embedding-models', 'flask', 'gensim', 'web-app', 'word2vec']
# ['babel-plugin', 'interop', 'migrate', 'react', 'seamless-integration', 'vue', 'vue-plugin']
# ['custom-component', 'home-assistant', 'homeassistant', 'iot', 'miio', 'miot', 'miot-spec', 'smart-home', 'xiaoai', 'xiaomi', 'xiaomi-miot']
# ['red-team']
# ['deep-learning', 'deep-neural-networks', 'prediction-uncertainty', 'uncertainty-estimation', 'uncertainty-quantification']
# ['alan-ai', 'alan-sdk', 'alan-studio', 'alan-voice', 'android', 'conversational-ai', 'machine-learning', 'multimodal', 'sdk', 'speech-recognition', 'text-to-speech', 'voice', 'voice-assistant', 'voice-commands', 'voice-control', 'voice-interface', 'vui']
# ['chatbot', 'conversational-ai', 'machine-learning', 'multimodal', 'speech-recognition', 'text-to-speech', 'voice-assistant', 'voice-commands', 'voice-interface', 'vui']
# ['alan-ionic-sdk', 'alan-studio', 'chatbot', 'conversational-ai', 'ionic', 'machine-learning', 'multimodal', 'sdk', 'speech-recognition', 'text-to-speech', 'voice', 'voice-ai', 'voice-assistant', 'voice-commands', 'voice-control', 'voice-interface', 'vui']
# ['alan-studio', 'alan-voice', 'chatbot', 'conversational-ai', 'machine-learning', 'microsoft-power-apps', 'multimodal', 'pcf', 'power-apps', 'sdk', 'speech-recognition', 'text-to-speech', 'tts', 'voice', 'voice-ai', 'voice-assistant', 'voice-commands', 'voice-control', 'voice-interface', 'vui']
# ['alan', 'alan-ai', 'alan-voice', 'android', 'chatbot', 'ios', 'multimodal', 'react-native', 'sdk', 'speech-recognition', 'text-to-speech', 'tts', 'voice', 'voice-ai', 'voice-assistant', 'voice-commands', 'voice-control', 'voice-interface', 'vui']
# ['ai', 'ai-assistant', 'ai-chat', 'ai-chat-bot', 'conversational-ai', 'custom-dataset', 'enterprise', 'explainable-ai', 'generative-ai', 'large-language-models', 'llms', 'low-code', 'machine-learning', 'nlp', 'productivity', 'question-answering', 'text-ai', 'voice-ai', 'voice-ai-platform', 'workflow']
# ['dependency-manager', 'pip', 'python']
# ['alfred-workflows', 'alfred4', 'alfred5', 'applescript', 'javascript', 'shell']
# ['functional-programming']
# ['component', 'machine-learning', 'react', 'redux', 'ui']
# ['geolocalization', 'osint', 'osint-tool', 'projet-fox', 'python', 'telegram', 'telegram-nearby-map', 'telegram-osint']
# ['machine-learning', 'optimization-algorithms', 'proximal-operators', 'signal-processing']
# ['awesome-list', 'deep-learning', 'medical-imaging', 'medical-informatics']
# ['answers', 'coursera', 'deep-learning', 'deeplearning-ai', 'programing-assignments']
# ['chinese', 'machine-learning-yearning', 'translation']
# ['albert', 'albertlauncher', 'application-launcher', 'cpp', 'keyboard-launcher', 'launcher', 'plugins', 'python', 'qt', 'qt6']
# ['automation', 'domotic', 'home-automation', 'iot', 'meross', 'meross-cloud', 'meross-devices', 'python']
# ['deep-learning', 'keras', 'model-zoo']
# ['finance', 'optimization', 'portfolio', 'quotes', 'yahoo-finance-api']
# ['brackets', 'quotes', 'visual-studio-code-extension']
# ['c', 'interpreter', 'parsers', 'pycparser', 'python']
# ['awesome', 'haskell', 'haskell-articles', 'haskell-learning', 'haskell-tutorial', 'learning-haskell']
# ['experimental-language', 'functional-programming', 'generic-functions', 'generic-types', 'golang', 'language']
# ['cloc', 'count-lines', 'programming-language']
# ['bitwarden', 'hashicorp-homelab', 'lazylibrarian', 'nomad', 'nomad-jobs', 'sabnzbd', 'sonarr']
# ['benchmarking', 'go', 'golang']
# ['command-line', 'commands', 'flags', 'go', 'golang', 'parser', 'struct', 'tags']
# ['ast', 'ebnf', 'go', 'golang', 'grammar', 'lexer', 'parser', 'parser-api', 'parser-framework', 'parser-library', 'participle']
# ['compiler', 'experiment', 'language', 'multi-syntax-language']
# ['awesome', 'awesome-list', 'engineering-strategy', 'strategy', 'tech-strategy']
# ['ios', 'machine-learning', 'metal', 'swift']
# ['python-gui-development', 'python-gui-programming', 'tkinter', 'tkinter-graphic-interface', 'tkinter-gui', 'tkinter-python']
# ['cat', 'cats', 'dcgan', 'deep-learning', 'gan', 'machine-learning', 'torch']
# ['deep-learning', 'face', 'gan', 'lua', 'torch']
# ['computer-vision', 'deep-learning', 'deep-reinforcement-learning', 'gan', 'machine-learning', 'nlp', 'paper', 'summary']
# ['autonomous', 'deep-learning', 'pytorch', 'reinforcement-learning', 'self-driving-car']
# ['graph', 'node-based', 'unity', 'unity-editor']
# ['multi-document-summarization', 'multi-news', 'summarization']
# ['auto-ml', 'automatic-machine-learning', 'automl', 'cross-validation', 'data-science', 'data-science-projects', 'hyperparameter-optimization', 'hyperparameter-tuning', 'machine-learning', 'machine-learning-library', 'machine-learning-models', 'ml', 'model-selection', 'optimisation', 'python', 'sklearn', 'stacking', 'stacking-ensemble', 'xgboost']
# ['reinforcement-learning']
# ['content-moderation', 'deep-learning', 'machine-learning', 'nsfw', 'nsfw-classifier', 'pornography']
# ['ai', 'alexa', 'alexa-skills-kit', 'amazon', 'amazon-alexa', 'amazon-alexa-skill', 'amazon-echo', 'java', 'sdk', 'skills', 'voice']
# ['alexa', 'alexa-sdk', 'alexa-skill', 'alexa-skill-development', 'alexa-skills-kit', 'python', 'sdk', 'sdk-python', 'skills', 'software-development-kit']
# ['alexa', 'alexapi', 'artificial-intelligence', 'assistant', 'voice-commands']
# ['alexa', 'alexa-skills-kit', 'skills', 'smart-home', 'smarthome']
# ['adb', 'android', 'automation', 'bot', 'follow', 'instabot', 'instagram', 'instagram-bot', 'like', 'mobile', 'python', 'script']
# ['ios', 'library', 'python', 'python-shortcuts', 'shortcut', 'shortcuts', 'siri', 'siri-shortcuts', 'toml']
# ['jquery-plugin']
# ['gaussian-mixture-models', 'machine-learning', 'python', 'regression']
# ['go', 'golang', 'patterns']
# ['alfred', 'alfred-workflow', 'deepl', 'deepl-alfred-workflow', 'workflow']
# ['behavior-driven-development', 'design-by-contract', 'finite-state-machine', 'hierarchical-state-machine', 'property-testing', 'python', 'statecharts', 'testing', 'uml']
# ['concurrency', 'concurrent-programming', 'functional-programming', 'go', 'go-tutorial', 'go-tutorials', 'golang', 'golang-tools', 'google', 'guide', 'hacking-code', 'hackingcode', 'learn-by-doing', 'learn-to-code', 'learning-by-doing', 'open-source', 'tutorial']
# ['obsidian-md', 'obsidian-plugin', 'table-sorting']
# ['generic-derivation', 'scala', 'scalacheck', 'shapeless']
# ['challenge', 'hackerrank', 'kaggle', 'machine-learning', 'python']
# ['miniprogram', 'sentry']
# ['alfred', 'alfred-workflow', 'ip', 'ip-address', 'ip-address-lookup', 'network', 'networking', 'workflow']
# ['atom', 'atom-package', 'javascript']
# ['email-validation', 'text-to-url', 'url-detection', 'url-validation', 'urls']
# ['lazarus', 'pascal', 'syntax-highlighting', 'text-editor']
# ['argument-parsing', 'golang']
# ['golang', 'serialization']
# ['golang', 'regular-expression']
# ['3d-packing', 'bin-packing', 'online-packing', 'packing-algorithm', 'reinforcement-learning']
# ['nltk', 'wikipedia']
# ['algorithms', 'arrays', 'c-plus-plus', 'cracking-the-coding-interview', 'dynamic-programming', 'graphs', 'python', 'queues', 'recursion', 'search', 'sorting-algorithms', 'stacks', 'strings', 'trees']
# ['approximate-bayesian-inference', 'deep-learning', 'laplace-approximation', 'neural-network']
# ['autonomous-quadcoptor', 'robotics-swarm', 'uav']
# ['go', 'golang', 'prealloc-suggestions', 'slice', 'static-analysis', 'static-analyzer', 'static-code-analysis']
# ['autocomplete', 'autosize', 'autosuggest', 'datepicker', 'dropdown', 'input', 'input-mask', 'javascript', 'react', 'typeahead']
# ['d3', 'deep-learning', 'diagrams', 'drawing', 'machine-learning', 'neural-network', 'svg', 'threejs']
# ['diffing', 'javascript', 'text']
# ['python']
# ['ast', 'language-extension', 'language-extensions', 'magic', 'python', 'python-ast', 'python3']
# ['awesome-go', 'awesome-golang', 'go', 'golang', 'golang-library', 'pattern-matching']
# ['python']
# ['javascript', 'memoization', 'memoize', 'performance']
# ['assert', 'assertion', 'invariant', 'type-guard']
# ['ai', 'llama', 'llamacpp', 'machine-learning', 'macos', 'swift', 'swiftui']
# ['artificial-intelligence', 'awesome-list', 'computer-vision', 'deep-learning', 'gpgpu', 'machine-learning', 'natural-language-processing', 'neural-network', 'speech-recognition', 'swift']
# ['animation', 'material', 'searchbar', 'stock-android', 'transition']
# ['android', 'bankholidays', 'birthdays', 'contacts', 'memento', 'memento-calendar', 'namedays', 'transitions', 'wiki']
# ['bert-ner', 'bert-wwm', 'bilstm-cnn', 'ccks', 'character-embeddings', 'entity-disambiguation', 'entity-linking', 'entity-recognition', 'knowledge-base', 'knowledge-graph']
# ['assistant', 'home-automation', 'jarvis', 'jasper', 'personal-assistant', 'raspberry-pi', 'sarah', 'voice-commands', 'voice-control', 'voice-recognition']
# ['android', 'android-dependency-visualizer', 'apk', 'apk-dependency-graph', 'architecture', 'decompile', 'dependency-injection', 'smali']
# ['api', 'arabic', 'django-application', 'indexing', 'python2', 'quran', 'search-engine']
# ['alfred', 'alfred-workflow', 'awesome', 'awesome-list', 'text-manipulation']
# ['elixir', 'elixir-lang', 'elixir-phoenix', 'gdscript', 'godot', 'godot-engine', 'godotengine', 'phoenix-framework']
# ['ai-chatbot', 'ai-chatbot-framework', 'chatbot', 'conversational-ai', 'hacktoberfest', 'help-wanted']
# ['build-library', 'glob', 'javascript-library', 'libraries', 'modular', 'multi-entry', 'plugin', 'rollup', 'rollup-bundle', 'rollup-plugin', 'typescript-library']
# ['atari', 'learning', 'machine-learning', 'open-source', 'paac', 'reinforcement', 'reinforcement-learning', 'tensorflow']
# ['diagram', 'diagrams', 'drawio', 'floorplan', 'flowchart', 'flowchart-diagrams', 'grafana', 'grafana-plugin', 'home-automation', 'monitoring', 'mxgraph', 'plugin-grafana', 'technical-architectures', 'visio']
# ['array', 'backtracking', 'bit-manipulation', 'data-structures-and-algorithms', 'dynamic-programming', 'graph', 'greedy-algorithms', 'hashing-algorithm', 'heap', 'linked-list', 'number-theory', 'queue', 'recursion', 'searching-algorithms', 'sorting-algorithms', 'stack', 'string', 'tree', 'trie']
# ['algolia', 'algolia-search', 'android', 'api-client', 'faceted-search', 'geo-search', 'instant-search', 'open-source', 'sdk', 'search', 'search-engine', 'search-synonyms']
# ...
# ['aiochan', 'asyncio', 'channel', 'concurrency', 'core-async', 'csp', 'golang', 'python']
# ['12306', 'captcha', 'deep-learning', 'mathematics']
# ['algorithm', 'leetcode']
# ['abp', 'abp-react-antd', 'ant-design', 'ant-design-pro', 'antd', 'net-core', 'react']
# ['picker', 'swift']
# ['ebook-reader', 'it']
# ['batchnorm', 'deep-learning', 'encoding-layer', 'synchronized-batchnorm']
# ['deep-learning', 'detectron-models', 'pytorch', 'resnest', 'resnet', 'split-attention-networks']
# ['jd', 'jingdong', 'python']
# ['python3']
# ['character-level', 'chinese', 'language-model', 'lstm', 'rnn']
# ['nlp', 'text-classification', 'transformers']
# ['association-analysis', 'c-plus-plus', 'genetics', 'genotype', 'gwas', 'kernel', 'meta-analysis', 'next-generation-sequencing', 'ngs', 'rare-variant', 'skat', 'umich', 'variants', 'vcf-files']
# ['fastapi']
# ['competition', 'emsembling', 'nlp', 'sohu', 'stacking']
# ['conditional-model', 'deep-learning', 'dynamic-convolution', 'few-shot-learning', 'filter-bank']
# ['html5', 'mui', 'mui-demo']
# ['ai', 'chatbot', 'nlp-machine-learning', 'python', 'pytorch', 'seq2seq-chatbot', 'seqgan', 'seqgan-tensorflow', 'tensorflow2']
# ['chatgpt', 'claude', 'gemini', 'gmail', 'slack', 'telegram', 'web']
# ['filter', 'sensitive', 'sensitive-word-filter']
# ['chess', 'chess-engine', 'stockfish']
# ['benchmark', 'chinese', 'language-model']
# ['acmmm2019', 'aim2019challenge', 'image-resolution', 'imdn', 'information-multi-distillation', 'lightweight', 'rtc2019', 'rte2020']
# ['aaai2020', 'gman', 'traffic-prediction']
# ['acfun', 'api', 'bangumi', 'bilibili', 'kodi', 'kodi-addon', 'kodi-plugin', 'python', 'video']
# ['deep-learning', 'interview', 'machine-learning']
# ['competition', 'data-mining', 'deep-learning', 'ecg', 'ecg-classification', 'multi-lead']
# ['deep-learning', 'nlp', 'python3', 'pytorch', 'relation-extraction']
# ['deep-learning', 'llm', 'machine-learning']
# ['gplv2', 'storyteller']
# ['gan', 'generative-adversarial-network', 'generative-model', 'semi-supervised-learning']
# ['deep-learning', 'deep-reinforcement-learning', 'deepmind', 'reinforcement-learning', 'ucl']
# ['attention-mechanism', 'deep-learning', 'lstm-neural-networks', 'paper-implementations', 'recurrent-neural-networks', 'rnn-pytorch']
# ['duplicate-questions-identification', 'natural-language-inference', 'paraphrase-identification', 'sentence-match', 'sentence-similarity']
# ['awesome', 'awesome-list', 'class-imbalance', 'deep-learning', 'ensemble-learning', 'fair-ml', 'fairness-ml', 'imbalanced-classes', 'imbalanced-classification', 'imbalanced-data', 'imbalanced-learning', 'machine-learning', 'skewed-data']
# ['artificial-intelligence', 'awesome', 'awesome-list', 'machine-learning', 'machine-learning-algorithms', 'neural-network']
# ['class-imbalance', 'classification', 'ensemble', 'ensemble-learning', 'ensemble-methods', 'ensemble-model', 'imbalance-classification', 'imbalanced-data', 'imbalanced-learn', 'imbalanced-learning', 'machine-learning', 'pypi', 'python3']
# ['deep-reinforcement-learning', 'gym', 'openai-gym', 'python', 'pytorch', 'reinforcement-learning', 'tensorflow', 'tensorflow2']
# ['crf', 'ner', 'nlp', 'pytorch', 'sequence-labeling']
# ['deeplearning', 'distant-supervision', 'nlp', 'pytorch', 'relation-extraction']
# ['chinese', 'chinese-language', 'linter', 'translation', 'zhlint']
# ['autonomous-vehicles', 'frenet-frames', 'front-wheel-feedback', 'hybrid-astar', 'lqr', 'motion-planning-algorithms', 'mpc', 'path-tracking', 'pathplanning', 'pure-pursuit', 'rear-wheel-feedback', 'stanley', 'stanley-controller', 'state-lattice-planner', 'tracking']
# ['c-sharp', 'crf', 'dotnet', 'machine-learning', 'nlp']
# ['elixir', 'erlang', 'memory', 'observer', 'performance', 'performance-dashboard', 'performance-visualization', 'profiling', 'recon']
# ['autofac', 'automapper', 'csredis', 'dotnet-core', 'fluentvalidation', 'freesql', 'nlog', 'swagger']
# ['documents', 'groupware', 'ocr', 'office', 'paperless', 'pdf', 'scanner']
# ['hearthstone', 'mercenaries', 'python']
# ['go', 'golang', 'tutorial']
# ['deep-learning', 'forecasting', 'pytorch', 'self-attention', 'time-series', 'transformer']
# ['bert', 'chinese', 'sequence-tagging']
# ['packer', 'unpacker']
# ['adversarial', 'freelb', 'iclr2020', 'natural-language']
# ['chinese-to-piniyn', 'chinese-translation', 'pinyin']
# ['person', 're-id', 're-identification', 're-ranking']
# ['convolutional-neural-network', 'deep-belief-network', 'long-short-term-memory', 'recurrent-neural-network', 'stacked-autoencoder', 'stacked-denoising-autoencoders', 'stacked-sparse-autoencoder', 'tensorflow', 'tsne']
# ['bert', 'nlp', 'pytorch']
# ['electron-app', 'hexoeditor', 'hexomarkdown', 'markdown', 'markdown-editor', 'moeditor']
# ['artificial-intelligence', 'attention', 'music-generation', 'text-to-music', 'transformer']
# ['zotero', 'zotero-if-pro-max', 'zotero-if-pro-max-cracked', 'zotero-plugin']
# ['pomodoro', 'pomodoro-app', 'pomodoro-clock', 'pomodoro-technique', 'pomodoro-timer', 'productivity', 'productivity-app', 'productivity-booster', 'productivity-timer', 'productivity-tool', 'time-management', 'time-management-app', 'time-management-tool', 'tomato', 'tomato-clock', 'tomato-timer']
# ['git', 'gradle', 'idea-plugin', 'intellij', 'java', 'jetbrains-ides', 'kotlin']
# ['decompiler', 'java']
# ['automatic-differentiation', 'differentiable-computing', 'machine-learning']
# ['compiler', 'language', 'zig']
# ['learn-regex', 'regex', 'regular-expression']
# ['argoverse', 'autonomous-driving', 'behavior-prediction', 'cvpr2023', 'motion-forecasting', 'motion-prediction', 'trajectory-prediction', 'waymo-open-dataset']
# ['cloud-native', 'deep-learning', 'deep-neural-networks', 'image-search', 'machine-learning', 'microservices', 'milvus']
# ['anomaly-detection', 'automl', 'forecasting', 'outlier-detection', 'time-series']
# ['deep-learning', 'pytorch']
# ['intellij', 'scala', 'zio']
# ['abstract-algebra', 'category-theory', 'functional-programming', 'scala', 'zio']
# ['emoji', 'lua', 'neovim', 'nerd-fonts']
# ['attention-mechanism', 'capsule-network', 'catastrophic-forgetting', 'continual-learning', 'knowledge-transfer', 'natural-language-processing', 'text-classification', 'transfer-learning', 'transformer-architecture']
# ['afm', 'criteo', 'ctr-prediction', 'dcn', 'deepcross', 'deepfm', 'factorization-machine', 'ffm', 'fm', 'matrix-factorization', 'ncf', 'neural-network', 'nfm', 'pnn', 'python3', 'recommender-system', 'tensorflow2', 'widedeep', 'xdeepfm']
# ['awesome-list', 'deep-learning', 'deep-neural-networks', 'deep-reinforcement-learning', 'information', 'information-bottleneck']
# ['chatbot', 'chatgpt', 'dataset', 'llm']
# ['caffe', 'convolution', 'deep-learning', 'deep-neural-networks', 'diy', 'graph-algorithms', 'inference', 'inference-engine', 'maxpooling', 'ncnn', 'pnnx', 'pytorch', 'relu', 'resnet', 'sigmoid', 'yolo', 'yolov5']
# ['drone-racing', 'minco', 'motion-planning', 'optimization', 'se3', 'trajectory']
# ['l-bfgs', 'lbfgs', 'nonlinear-optimization', 'nonsmooth-optimization', 'optimization', 'smooth-functions', 'unconstrained-optimization']
# ['distributed-training', 'kgqa', 'knowledge-computing']
# ['intrinsicdecomposition', 'inverserendering', 'nerf']
# ['crowdsensing', 'crowdsourcing', 'urban-computing']
# ['deep-learning', 'knowledge-graph', 'knowledge-graph-completion', 'knowledge-graph-embeddings', 'link-prediction', 'machine-learning', 'neuralkg', 'python', 'pytorch-lightning']
# ['attribute-extraction', 'chinese', 'deep-learning', 'deepke', 'document-level', 'few-shot', 'information-extraction', 'instructie', 'kg', 'knowledge-graph', 'knowprompt', 'lightner', 'low-resource', 'multi-modal', 'named-entity-recognition', 'ner', 'nlp', 'prompt', 'pytorch', 'relation-extraction']
# ['api', 'chain-of-thought', 'chatgpt', 'easyinstruct', 'gpt', 'gpt-3', 'in-context-learning', 'instructions', 'knowlm', 'large-language-models', 'llama', 'multimodal', 'prompt', 'prompting', 'pypy-library', 'python', 'reasoning', 'tool']
# ['bilingual', 'chinese', 'deep-learning', 'deepspeed', 'english', 'gpt-3', 'instructie', 'instruction-following', 'instruction-tuning', 'instructions', 'knowlm', 'language-model', 'large-language-models', 'llama', 'lora', 'models', 'pre-trained-language-models', 'pre-trained-model', 'pre-training', 'reasoning']
# ['arithmetic-reasoning', 'artificial-intelligence', 'awsome-list', 'chain-of-thought', 'chatgpt', 'commonsense-reasoning', 'datasets', 'gpt-3', 'language-models', 'large-language-models', 'llm', 'logical-reasoning', 'natural-language-processing', 'nlp', 'paper-list', 'prompt', 'prompt-engineering', 'reasoning', 'survey', 'symbolic-reasoning']
# ['awsome-list', 'demo-tuning', 'dialogue', 'genkgc', 'knowledge-graph', 'knowledge-informed-prompt-learning', 'lambdakg', 'link-prediction', 'natural-language-processing', 'nlp', 'paper', 'paper-list', 'prompt-tuning', 'promptkg', 'pytorch', 'question-answering', 'relation-extraction', 'retrieval-augmented', 'retrievalre', 'retroprompt']
# ['cli', 'notes', 'second-brain', 'wiki', 'zettelkasten']
# ['cli', 'npm', 'package-manager']
# ['ascii-game', 'ascii-graphics', 'game', 'go', 'golang', 'procedural-generation', 'terminal-game']
# ['siamese-fc', 'siamese-network', 'siamrpn', 'siamvgg', 'tracking']
# ['cifar', 'dfn', 'ensemble', 'fusion', 'imagenet', 'mxnet', 'resnet']
# ['django', 'document-management', 'knowledge-management', 'markdown', 'notes-app', 'python', 'wiki']
# ['access-token', 'api', 'boilerplate', 'data-access-layer', 'enterprise', 'flux', 'http-wrapper', 'jwt', 'realworld', 'refresh-token', 'spa', 'vue-boilerplate', 'vuejs', 'vuex']
# ['boilerplate', 'shareable-components', 'vue', 'vue-plugin']
# ['build-tool', 'compiler', 'npm', 'package', 'vue']
# ['awesome', 'awesome-list', 'bot', 'bots', 'emoji', 'tweets', 'twitter', 'twitter-bot']
# ['acgan', 'began', 'cgan', 'collection', 'conditional-gan', 'dragan', 'ebgan', 'fashion-mnist', 'gan', 'generative-adversarial-network', 'infogan', 'lsgan', 'mnist', 'package', 'pytorch', 'wgan', 'wgan-gp']
# ['cdcgan', 'celeba', 'cgan', 'conditional-dcgan', 'conditional-gan', 'gender', 'generative-adversarial-network', 'mnist', 'pytorch']
# ['cgan', 'conditional-gan', 'gan', 'generative-adversarial-network', 'mnist', 'tensorflow']
# ['ethereum', 'language', 'snark', 'verifiable-computation', 'zero-knowledge', 'zksnarks']
# ['multicategory-segmentation', 'multiple-classification', 'nested', 'nested-multiple', 'nested-multiple-classification', 'unet', 'unet-multiple', 'unet-multiple-classification', 'unet-nested']
# ['multiprocessing', 'multithreading', 'pyqt5', 'python']
# ['custom-uibutton', 'google-material', 'ios-swift', 'uibutton']
# ['ios', 'ios-ui', 'objective-c', 'token-field', 'tokenfield']
# ['android', 'globalization', 'i18n', 'internationalization', 'ios', 'language-detection', 'react-native']
# ['dsl', 'elixir', 'pipelines', 'railway-oriented-programming']
# ['bootstrap4', 'django', 'python']
# ['algorithm', 'ipynb', 'k-nearest-neighbor', 'k-nearest-neighbours', 'k-nn', 'kmeans', 'linear-regression', 'logistic-regression', 'machine-learning', 'machine-learning-algorithms', 'neural-network', 'neural-networks', 'perceptron', 'python', 'python-implementations', 'python3']
# ['100daysofcode', 'coding', 'coding-challenge', 'python', 'python-3']
# ['c', 'cpython', 'cpython-internals', 'interpreter', 'learning-material', 'python', 'python3']
# ['c', 'learning-material', 'redis', 'redis-internals']
# ['cnn-text-classification', 'doc2vec-word2vec', 'keras', 'lstm', 'machine-learning', 'nlp', 'pytorch']
# ['c-plus-plus', 'game-development', 'game-engine', 'open-source', 'zelda-like']
# ['alfred-workflow', 'amazon', 'baidu', 'bangumi', 'bilibili', 'brave-search', 'duckduckgo', 'google', 'imdb', 'jingdong', 'moegirlpedia', 'pixiv', 'search-api', 'sina-weibo', 'taobao', 'wikipedia', 'wolfram-alpha', 'zhihu']
# ['golang', 'mechanical-keyboard', 'qmk']
# ['python', 'taskflow']
# ['gin-gonic', 'go', 'middleware', 'prometheus']
# ['deep-learning', 'gan', 'machine-learning', 'tensorflow', 'tensorlayer']
# ['deep-learning', 'efficientnet', 'pytorch']
# ['laravel', 'mixed-judge', 'njupt', 'noj', 'online-judge', 'onlinejudge', 'php', 'php7', 'virtual-judge']
# ['autocomplete', 'autosuggest', 'fish', 'shell', 'zsh', 'zsh-autosuggestions']
# ['command-history', 'fish-shell', 'history-search', 'zsh-plugins']
# ['article-series', 'book', 'rust']
# ['ai', 'algorithms', 'artificial-intelligence', 'books', 'data-mining', 'deep-learning', 'learning', 'machine-learning', 'mathematics', 'pdf', 'playground', 'quantum-algorithms', 'quantum-computing', 'quantum-information', 'reading', 'reinforcement-learning']
# ['algorithms', 'cpp', 'cpp17', 'data-structures', 'stl']
# ['artificial-intelligence', 'cloud', 'cloud-gpus', 'deep-learning', 'deeplearning', 'gpu', 'gpu-computing', 'machine-learning', 'mlops']
# ['ctf-tools', 'io-library', 'pwnable', 'pwntools', 'zio']
# ['bot', 'golang', 'keyword', 'telegram']
# ['python', 'python3', 'zulip']
# ['ai', 'dual-algorithm', 'game-development', 'minimax', 'negamax', 'sss-algorithm', 'two-player']
# ['android', 'anime', 'kotlin', 'myanimelist', 'reddit']
# ['artificial-intelligence', 'cem', 'cmaes', 'ddpg', 'deep-deterministic-policy-gradient', 'deep-learning', 'deep-reinforcement-learning', 'evolution-strategies', 'machine-learning', 'mujoco', 'policy-gradient', 'ppo', 'proximal-policy-optimization', 'python', 'pytorch', 'reinforcement-learning', 'research', 'sac', 'soft-actor-critic', 'td3']
# ['automation', 'automationtool', 'cli', 'go', 'golang', 'golang-cli', 'hacktoberfest', 'opensource', 'ritchie-cli', 'ritchie-formulas']
# ['deep-learning', 'machine-learning', 'python', 'tensorflow', 'watermark-image']
# ['deep-learning', 'euroscipy', 'gan', 'pycon', 'tensorflow', 'tensorflow-tutorials', 'tfgan', 'tutorial']
# ['artificial-intelligence', 'deep-learning', 'machine-learning', 'machine-learning-algorithms', 'software-engineer']
# ['hunspell', 'spellcheck', 'spellchecker', 'spelling']
# ['bot', 'facebook-graph-api', 'information-gathering']
# ['artificial-intelligence', 'auto-tuning', 'compiler', 'machine-learning', 'multi-cores', 'operating-systems', 'optimisation', 'parallel-computing', 'parallel-programming', 'parallelisation', 'parallelism']
# ['dynamical-systems', 'finite-difference-method', 'partial-differential-equations', 'pdes', 'python', 'scientific-computing']
# ['iccv2019', 'mot', 'multi-modality']
# ['quantum', 'quantum-computing', 'quantum-programming-language', 'unitaryhack']
# ['compiler', 'golang', 'lua', 'vm']
# ['chinese-translation', 'explained', 'john-whitington', 'oreilly-books', 'pdf', 'pdftk']
# ['ai', 'ebonite', 'machine-learning', 'python']
# ['gradient-boosting', 'gradient-boosting-classifier', 'hyperparameter-optimization', 'hyperparameter-tuning', 'hyperparameters', 'machine-learning']
# ['game-development', 'godot-engine', 'heightmap', 'terrain']
# ['deep-learning', 'dynamical-modeling', 'dynamical-systems', 'hamiltonian-dynamics', 'implicit-models', 'ode', 'ode-solver', 'ordinary-differential-equations', 'root-finding']
# ['discord-bot', 'princess-connect-redive', 'qqbot', 'telegram-bot', 'tomon-bot']
# ['deep-learning', 'machine-learning', 'neural-network', 'object-detection', 'tensorflow', 'tensorflow-examples', 'tensorflow-tutorials', 'tf2', 'yolo', 'yolov3']
# ['lowpoly']
# ['audio', 'automatic-speech-recognition', 'chinese-speech-recognition', 'cnn', 'data-preprocessing', 'deep-learning', 'end-to-end', 'evaluation', 'feature-vector', 'layer-normalization', 'lstm', 'paper', 'phonemes', 'rnn', 'rnn-encoder-decoder', 'speech-recognition', 'tensorflow', 'timit-dataset']
# ['acoustic-model', 'attention-mechanism', 'automatic-speech-recognition', 'cnn', 'diffusion-models', 'dnn', 'language-model', 'neural-network', 'papers', 'recognition-synthesis', 'rnn', 'roadmap', 'seq2seq', 'singing-voice-synthesis', 'speaker-verification', 'speech-recognition', 'speech-synthesis', 'timit-dataset', 'tts', 'voice-conversion']
# ['nlp']
# ['csharp', 'dotnet', 'eval', 'eval-expression', 'evaluation', 'evaluator']
# ['eval', 'evaluation', 'evaluator', 'expression-evaluator', 'regular-expression', 'splitting-text', 'sql', 'sql-server']
