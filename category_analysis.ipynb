# %%
import pandas as pd
df = pd.read_csv("C:/Users/29400/Desktop/data/original_data.csv")

# %%
df
# Out:
#         Unnamed: 0                                                url  \
# 0                0   https://api.github.com/repos/0-1-0/lightblue-0.4
# 1                1  https://api.github.com/repos/0-8-4/miui-auto-t...
# 2                2  https://api.github.com/repos/00-Evan/shattered...
# 3                3      https://api.github.com/repos/0015/ThatProject
# 4                4  https://api.github.com/repos/007revad/Synology...
# ...            ...                                                ...
# 185871      185871  https://api.github.com/repos/zzzprojects/Syste...
# 185872      185872  https://api.github.com/repos/zzzprojects/Syste...
# 185873      185873  https://api.github.com/repos/zzzprojects/Z.Ext...
# 185874      185874           https://api.github.com/repos/zzzzbw/Fame
# 185875      185875  https://api.github.com/repos/zzzzzzzzyt/zeng-r...
#
#                             name        owner  forks  stars  \
# 0                  lightblue-0.4        0-1-0     91     95
# ...
